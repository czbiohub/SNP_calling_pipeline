# %%
import pandas as pd
import os

# %%
ROI_df = pd.read_csv('batch_files/coverageBatch_comb.csv')
ROI_df
# Out:
#     chrom  start_pos    end_pos                 outfile
# 0      17    7674241    7674241              TP53_S241F
# 1       7   55161562   55161562              EGFR_R521K
# 2       2  177234076  177234076             NFE2L2_G81S
# 3       7   55174773   55174787  EGFR_E746_A750delELREA
# 4      17    7674239    7674239              TP53_C242S
# 5       2  177231362  177231362            NFE2L2_S414N
# 6      13   32332592   32332592             BRCA2_N372H
# 7      17    7676215    7676215               TP53_L52P
# 8      17    7676154    7676154               TP53_P72R
# 9      19   10492087   10492087             KEAP1_R272H
# 10      2  177231085  177231085            NFE2L2_K506N
# 11     12   25245351   25245351               KRAS_G12C
# 12      7   55174771   55174785         EGFR_K745_A750T
# 13     17    7676040    7676040              TP53_Y110C
# 14     19    4095413    4095413            MAP2K2_D341N
# 15     19   10486751   10486751             KEAP1_S592R
# ...

# %%
currPATH = os.getcwd()
cell_files_list = os.listdir('vcf/')
cells_list = []

for item in cell_files_list:
    curr = item.strip('.vcf')
    cells_list.append(curr)
    
cells_list
# Out:
# ['A11_1001000408',
#  'A7_B001545',
#  'A22_B003771',
#  'A22_1001000407',
#  'A21_B003528',
#  'A22_B003995',
#  'A7_B003187',
#  'A10_B001007',
#  'A13_B003529',
#  'A8_B003125',
#  'A3_B003067',
#  'A1_B003132',
#  'A12_B002077',
#  'A1_1001000295',
#  'A5_B001558',
#  'A22_B001007',
#  'A16_B000420',
#  'A16_B003129',
#  'A11_B003119',
#  'A21_B003105',
#  'A18_B003654',
#  'A14_B003518',
#  'A13_B003528',
#  'A19_B002097',
#  'A1_B003523',
#  'A17_B002073',
#  'A14_B003120',
#  'A18_B003522',
#  'A4_B002572',
#  'A9_B001007',
#  'A16_B003920',
#  'A19_1001000408',
#  'A13_B003112',
#  'A10_B001548',
#  'A14_B002572',
#  'A11_B003523',
#  'A8_B000573',
#  'A15_B003776',
#  'A16_1001000408',
#  'A6_B001474',
#  'A22_B002097',
#  'A3_B003528',
#  'A8_B003132',
#  'A8_B003126',
#  'A5_B000862',
#  'A3_B003070',
#  'A2_B001557',
#  'A2_B001543',
#  'A15_B002078',
#  'A6_B003129',
#  'A16_B003116',
#  'A19_B003995',
#  'A22_B001010',
#  'A3_1001000408',
#  'A15_B002079',
# ...

# %%
ROIs = list(ROI_df['outfile'])
ROIs
# Out:
# ['TP53_S241F',
#  'EGFR_R521K',
#  'NFE2L2_G81S',
#  'EGFR_E746_A750delELREA',
#  'TP53_C242S',
#  'NFE2L2_S414N',
#  'BRCA2_N372H',
#  'TP53_L52P',
#  'TP53_P72R',
#  'KEAP1_R272H',
#  'NFE2L2_K506N',
#  'KRAS_G12C',
#  'EGFR_K745_A750T',
#  'TP53_Y110C',
#  'MAP2K2_D341N',
#  'KEAP1_S592R',
#  'SMARCA4_R521W',
#  'SMARCA4_A509S',
#  'KEAP1_R116W',
#  'EGFR_G42D',
#  'KEAP1_T142M',
#  'KEAP1_G423V',
#  'MAP2K2_R299M',
#  'EGFR_L858R',
#  'KEAP1_R483H',
#  'KEAP1_V271M',
#  'TP53_V175L',
#  'SMARCA4_G394W',
#  'NFE2L2_H416Y',
#  'KEAP1_Q284*',
#  'KEAP1_Q75*',
#  'TP53_A7V',
#  'TP53_E180K',
#  'MAP2K2_F338Y',
#  'MAP2K2_P22S',
#  'NFE2L2_V417L',
#  'TP53_R123W',
#  'TP53_G146W',
#  'MAP2K1_F53L',
#  'MET_K305*',
#  'KRAS_G13D',
#  'EGFR_A237V',
#  'KEAP1_D389Y',
#  'TP53_G245D',
#  'NFE2L2_D29H',
#  'KEAP1_E117K',
#  'TP53_R282W',
#  'SMARCA4_A1448V',
#  'NFE2L2_E82D',
#  'KRAS_A146P',
#  'KRAS_Q61H',
#  'BRCA2_N289H',
#  'TP53_L111Q',
#  'KEAP1_V155A',
#  'KEAP1_A191T',
# ...

# %%
ROIs.insert(0,'cell')
ROIs
# Out:
# ['cell',
#  'TP53_S241F',
#  'EGFR_R521K',
#  'NFE2L2_G81S',
#  'EGFR_E746_A750delELREA',
#  'TP53_C242S',
#  'NFE2L2_S414N',
#  'BRCA2_N372H',
#  'TP53_L52P',
#  'TP53_P72R',
#  'KEAP1_R272H',
#  'NFE2L2_K506N',
#  'KRAS_G12C',
#  'EGFR_K745_A750T',
#  'TP53_Y110C',
#  'MAP2K2_D341N',
#  'KEAP1_S592R',
#  'SMARCA4_R521W',
#  'SMARCA4_A509S',
#  'KEAP1_R116W',
#  'EGFR_G42D',
#  'KEAP1_T142M',
#  'KEAP1_G423V',
#  'MAP2K2_R299M',
#  'EGFR_L858R',
#  'KEAP1_R483H',
#  'KEAP1_V271M',
#  'TP53_V175L',
#  'SMARCA4_G394W',
#  'NFE2L2_H416Y',
#  'KEAP1_Q284*',
#  'KEAP1_Q75*',
#  'TP53_A7V',
#  'TP53_E180K',
#  'MAP2K2_F338Y',
#  'MAP2K2_P22S',
#  'NFE2L2_V417L',
#  'TP53_R123W',
#  'TP53_G146W',
#  'MAP2K1_F53L',
#  'MET_K305*',
#  'KRAS_G13D',
#  'EGFR_A237V',
#  'KEAP1_D389Y',
#  'TP53_G245D',
#  'NFE2L2_D29H',
#  'KEAP1_E117K',
#  'TP53_R282W',
#  'SMARCA4_A1448V',
#  'NFE2L2_E82D',
#  'KRAS_A146P',
#  'KRAS_Q61H',
#  'BRCA2_N289H',
#  'TP53_L111Q',
#  'KEAP1_V155A',
#  'KEAP1_A191T',
# ...

# %%
big_df = pd.DataFrame(columns=ROIs)
big_df
# Out:
# Empty DataFrame
# ...

# %%
big_df['cell'] = cells_list
big_df
# Out:
#                cell TP53_S241F EGFR_R521K NFE2L2_G81S EGFR_E746_A750delELREA  \
# 0    A11_1001000408        NaN        NaN         NaN                    NaN
# 1        A7_B001545        NaN        NaN         NaN                    NaN
# 2       A22_B003771        NaN        NaN         NaN                    NaN
# 3    A22_1001000407        NaN        NaN         NaN                    NaN
# 4       A21_B003528        NaN        NaN         NaN                    NaN
# 5       A22_B003995        NaN        NaN         NaN                    NaN
# 6        A7_B003187        NaN        NaN         NaN                    NaN
# 7       A10_B001007        NaN        NaN         NaN                    NaN
# 8       A13_B003529        NaN        NaN         NaN                    NaN
# 9        A8_B003125        NaN        NaN         NaN                    NaN
# 10       A3_B003067        NaN        NaN         NaN                    NaN
# ...

# %%
cellRow = big_df['cell'] == 'A21_B003528'
big_df[cellRow]
big_df.loc[cellRow, 'TP53_S241F'] = 1
big_df
# Out:
#                cell TP53_S241F EGFR_R521K NFE2L2_G81S EGFR_E746_A750delELREA  \
# 0    A11_1001000408        NaN        NaN         NaN                    NaN
# 1        A7_B001545        NaN        NaN         NaN                    NaN
# 2       A22_B003771        NaN        NaN         NaN                    NaN
# 3    A22_1001000407        NaN        NaN         NaN                    NaN
# 4       A21_B003528          1        NaN         NaN                    NaN
# 5       A22_B003995        NaN        NaN         NaN                    NaN
# 6        A7_B003187        NaN        NaN         NaN                    NaN
# 7       A10_B001007        NaN        NaN         NaN                    NaN
# 8       A13_B003529        NaN        NaN         NaN                    NaN
# 9        A8_B003125        NaN        NaN         NaN                    NaN
# 10       A3_B003067        NaN        NaN         NaN                    NaN
# ...
