# %%
# vcf reader

# %%
from collections import OrderedDict
import gzip
import pandas as pd

# %%
def _count_comments(filename):
    """Count comment lines (those that start with "#") in an optionally
    gzipped file.
    :param filename:  An optionally gzipped file.
    """
    #print('in _count_comments')
    comments = 0
    fn_open = gzip.open if filename.endswith('.gz') else open
    with fn_open(filename) as fh:
        for line in fh:
            if line.startswith('#'):
                comments += 1
            else:
                break
    return comments

# %%
VCF_HEADER = ['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', '20']


def my_dataframe(filename, large=True):
    """Open an optionally gzipped VCF file and return a pandas.DataFrame with
    each INFO field included as a column in the dataframe.
    Note: Using large=False with large VCF files. It will be painfully slow.
    :param filename:    An optionally gzipped VCF file.
    :param large:       Use this with large VCF files to skip the ## lines and
                        leave the INFO fields unseparated as a single column.
    """
    #print('here i am!')
    if large:
        # Set the proper argument if the file is compressed.
        comp = 'gzip' if filename.endswith('.gz') else None
        # Count how many comment lines should be skipped.
        comments = _count_comments(filename)
        # Return a simple DataFrame without splitting the INFO column.
        return pd.read_table(filename, compression=comp, skiprows=comments,
                             names=VCF_HEADER, usecols=range(10))

    # Each column is a list stored as a value in this dict. The keys for this
    # dict are the VCF column names and the keys in the INFO column.
    result = OrderedDict()
    # Parse each line in the VCF file into a dict.
    for i, line in enumerate(lines(filename)):
        for key in line.keys():
            # This key has not been seen yet, so set it to None for all
            # previous lines.
            if key not in result:
                result[key] = [None] * i
        # Ensure this row has some value for each column.
        for key in result.keys():
            result[key].append(line.get(key, None))

    return pd.DataFrame(result)

# %%
my_dataframe('./vcf/O15_B003776_unfilt.vcf')
# Out:
# /Users/lincoln.harris/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#             CHROM     POS           ID  REF   ALT     QUAL FILTER  \
# 0            chr1   14610            .    T     C    62.74      .
# 1            chr1   14640            .    C     T    56.74      .
# 2            chr1  629906    rs1578391    C     T   314.77      .
# 3            chr1  630026    rs6594029    C     T    60.94      .
# 4            chr1  630161    rs6594031    A     G    56.74      .
# 5            chr1  630211    rs7416152    C     T   180.90      .
# 6            chr1  630317    rs3021087    A     G   305.78      .
# 7            chr1  630490            .    T     C   127.03      .
# 8            chr1  630557    rs7417504    T     C    15.65      .
# 9            chr1  630596            .    C     T    15.65      .
# 10           chr1  631193    rs1856866    A     G    95.28      .
# 11           chr1  631436            .    C     A    14.68      .
# 12           chr1  631469            .    G     A    15.65      .
# 13           chr1  631536            .    A     G    18.59      .
# 14           chr1  631553  rs113120793    A     G    18.59      .
# 15           chr1  631622            .    T     C   139.03      .
# 16           chr1  631653            .    T     C   127.03      .
# 17           chr1  631712    rs9326622    T     C   139.03      .
# 18           chr1  631739    rs9283153    A     C   130.96      .
# 19           chr1  631811            .    C     T   285.78      .
# 20           chr1  631862            .    G     A  2339.77      .
# 21           chr1  632106            .    T     C    18.59      .
# 22           chr1  632109            .    T     C    18.59      .
# 23           chr1  632199            .    C     T   610.77      .
# 24           chr1  632317    rs1972379    G     A   202.84      .
# 25           chr1  632403            .    T     C   134.03      .
# 26           chr1  632427    rs2853819    T     C    62.74      .
# 27           chr1  632487    rs2000096    A     G   107.98      .
# 28           chr1  632821            .    T     C    15.65      .
# 29           chr1  632876    rs4098612    C     T    55.74      .
# ...           ...     ...          ...  ...   ...      ...    ...
# 49548  ERCC-00043      37            .    G    GT   202.73      .
# 49549  ERCC-00046     160            .    A    AT    55.73      .
# 49550  ERCC-00046     170            .    G    GT   125.73      .
# 49551  ERCC-00046     340            .    T     C   336.77      .
# 49552  ERCC-00074     365            .    A     T   477.77      .
# 49553  ERCC-00074     489            .    G    GA    19.78      .
# 49554  ERCC-00074     497            .    C     A    28.77      .
# 49555  ERCC-00074     499            .    A     T    40.77      .
# 49556  ERCC-00092     554            .    G     A    10.20      .
# 49557  ERCC-00096     460            .    A     G   164.77      .
# 49558  ERCC-00108     321            .    G     A   295.77      .
# 49559  ERCC-00108     660            .    C     T   131.77      .
# 49560  ERCC-00113     328            .    G     A   196.77      .
# 49561  ERCC-00113     489            .    G     A  1421.77      .
# 49562  ERCC-00113     552            .  TAA     T  2268.73      .
# 49563  ERCC-00116     299            .    C     T   272.77      .
# 49564  ERCC-00116     521            .    G     A    48.77      .
# 49565  ERCC-00116     696            .    C     T   179.77      .
# 49566  ERCC-00116     949            .    G     A    49.77      .
# 49567  ERCC-00116    1270            .    G     T    48.77      .
# 49568  ERCC-00116    1329            .    C     A   376.77      .
# 49569  ERCC-00130      69            .   GC     G   252.73      .
# 49570  ERCC-00130     552            .    A     G   355.77      .
# 49571  ERCC-00130    1002            .    A     G    41.77      .
# 49572  ERCC-00131     261            .    A  AAAT   748.73      .
# 49573  ERCC-00131     263            .  TGC     T   747.73      .
# 49574  ERCC-00131     439            .    G     A   143.77      .
# 49575  ERCC-00171     202            .    A    AG    74.73      .
# 49576  ERCC-00171     214            .    T     C   123.77      .
# 49577  ERCC-00171     325            .    C     T    74.77      .
#
#                                                     INFO          FORMAT  \
# 0      AC=2;AF=1.00;AN=2;DP=11;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 1      AC=2;AF=1.00;AN=2;DP=38;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 2      AC=2;AF=1.00;AN=2;DB;DP=253;ExcessHet=3.0103;F...  GT:AD:DP:GQ:PL
# 3      AC=2;AF=1.00;AN=2;DB;DP=70;ExcessHet=3.0103;FS...  GT:AD:DP:GQ:PL
# 4      AC=2;AF=1.00;AN=2;DB;DP=5;ExcessHet=3.0103;FS=...  GT:AD:DP:GQ:PL
# 5      AC=2;AF=1.00;AN=2;DB;DP=44;ExcessHet=3.0103;FS...  GT:AD:DP:GQ:PL
# 6      AC=2;AF=1.00;AN=2;DB;DP=72;ExcessHet=3.0103;FS...  GT:AD:DP:GQ:PL
# 7      AC=2;AF=1.00;AN=2;DP=21;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 8      AC=2;AF=1.00;AN=2;DB;DP=2;ExcessHet=3.0103;FS=...  GT:AD:DP:GQ:PL
# 9      AC=2;AF=1.00;AN=2;DP=3;ExcessHet=3.0103;FS=0.0...  GT:AD:DP:GQ:PL
# 10     AC=2;AF=1.00;AN=2;DB;DP=64;ExcessHet=3.0103;FS...  GT:AD:DP:GQ:PL
# 11     AC=2;AF=1.00;AN=2;DP=19;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 12     AC=2;AF=1.00;AN=2;DP=35;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 13     AC=2;AF=1.00;AN=2;DP=31;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 14     AC=2;AF=1.00;AN=2;DB;DP=20;ExcessHet=3.0103;FS...  GT:AD:DP:GQ:PL
# 15     AC=2;AF=1.00;AN=2;DP=13;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 16     AC=2;AF=1.00;AN=2;DP=8;ExcessHet=3.0103;FS=0.0...  GT:AD:DP:GQ:PL
# 17     AC=2;AF=1.00;AN=2;DB;DP=58;ExcessHet=3.0103;FS...  GT:AD:DP:GQ:PL
# 18     AC=2;AF=1.00;AN=2;DB;DP=66;ExcessHet=3.0103;FS...  GT:AD:DP:GQ:PL
# 19     AC=2;AF=1.00;AN=2;DP=67;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 20     AC=2;AF=1.00;AN=2;DP=332;ExcessHet=3.0103;FS=0...  GT:AD:DP:GQ:PL
# 21     AC=2;AF=1.00;AN=2;DP=35;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 22     AC=2;AF=1.00;AN=2;DP=67;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 23     AC=2;AF=1.00;AN=2;DP=2139;ExcessHet=3.0103;FS=...  GT:AD:DP:GQ:PL
# 24     AC=2;AF=1.00;AN=2;DB;DP=83;ExcessHet=3.0103;FS...  GT:AD:DP:GQ:PL
# 25     AC=2;AF=1.00;AN=2;DP=49;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 26     AC=2;AF=1.00;AN=2;DB;DP=24;ExcessHet=3.0103;FS...  GT:AD:DP:GQ:PL
# 27     AC=2;AF=1.00;AN=2;DB;DP=94;ExcessHet=3.0103;FS...  GT:AD:DP:GQ:PL
# 28     AC=2;AF=1.00;AN=2;DP=4;ExcessHet=3.0103;FS=0.0...  GT:AD:DP:GQ:PL
# 29     AC=2;AF=1.00;AN=2;DB;DP=3;ExcessHet=3.0103;FS=...  GT:AD:DP:GQ:PL
# ...                                                  ...             ...
# 49548  AC=1;AF=0.500;AN=2;DP=36;ExcessHet=3.0103;FS=0...  GT:AD:DP:GQ:PL
# 49549  AC=1;AF=0.500;AN=2;DP=85;ExcessHet=3.0103;FS=4...  GT:AD:DP:GQ:PL
# 49550  AC=1;AF=0.500;AN=2;DP=85;ExcessHet=3.0103;FS=9...  GT:AD:DP:GQ:PL
# 49551  AC=1;AF=0.500;AN=2;DP=48;ExcessHet=3.0103;FS=0...  GT:AD:DP:GQ:PL
# 49552  AC=1;AF=0.500;AN=2;DP=377;ExcessHet=3.0103;FS=...  GT:AD:DP:GQ:PL
# 49553  AC=1;AF=0.500;AN=2;DP=11;ExcessHet=3.0103;FS=0...  GT:AD:DP:GQ:PL
# 49554  AC=1;AF=0.500;AN=2;DP=11;ExcessHet=3.0103;FS=0...  GT:AD:DP:GQ:PL
# 49555  AC=1;AF=0.500;AN=2;DP=4;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 49556  AC=1;AF=0.500;AN=2;DP=25;ExcessHet=3.0103;FS=0...  GT:AD:DP:GQ:PL
# 49557  AC=1;AF=0.500;AN=2;DP=425;ExcessHet=3.0103;FS=...  GT:AD:DP:GQ:PL
# 49558  AC=1;AF=0.500;AN=2;DP=41;ExcessHet=3.0103;FS=6...  GT:AD:DP:GQ:PL
# 49559  AC=1;AF=0.500;AN=2;DP=64;ExcessHet=3.0103;FS=5...  GT:AD:DP:GQ:PL
# 49560  AC=1;AF=0.500;AN=2;DP=107;ExcessHet=3.0103;FS=...  GT:AD:DP:GQ:PL
# 49561  AC=1;AF=0.500;AN=2;DP=113;ExcessHet=3.0103;FS=...  GT:AD:DP:GQ:PL
# 49562  AC=1;AF=0.500;AN=2;DP=247;ExcessHet=3.0103;FS=...  GT:AD:DP:GQ:PL
# 49563  AC=1;AF=0.500;AN=2;DP=55;ExcessHet=3.0103;FS=9...  GT:AD:DP:GQ:PL
# 49564  AC=1;AF=0.500;AN=2;DP=16;ExcessHet=3.0103;FS=2...  GT:AD:DP:GQ:PL
# 49565  AC=1;AF=0.500;AN=2;DP=48;ExcessHet=3.0103;FS=1...  GT:AD:DP:GQ:PL
# 49566  AC=1;AF=0.500;AN=2;DP=25;ExcessHet=3.0103;FS=2...  GT:AD:DP:GQ:PL
# 49567  AC=1;AF=0.500;AN=2;DP=30;ExcessHet=3.0103;FS=1...  GT:AD:DP:GQ:PL
# 49568  AC=1;AF=0.500;AN=2;DP=32;ExcessHet=3.0103;FS=1...  GT:AD:DP:GQ:PL
# 49569  AC=1;AF=0.500;AN=2;DP=145;ExcessHet=3.0103;FS=...  GT:AD:DP:GQ:PL
# 49570  AC=1;AF=0.500;AN=2;DP=572;ExcessHet=3.0103;FS=...  GT:AD:DP:GQ:PL
# 49571  AC=1;AF=0.500;AN=2;DP=131;ExcessHet=3.0103;FS=...  GT:AD:DP:GQ:PL
# 49572  AC=1;AF=0.500;AN=2;DP=22;ExcessHet=3.0103;FS=3...  GT:AD:DP:GQ:PL
# 49573  AC=1;AF=0.500;AN=2;DP=38;ExcessHet=3.0103;FS=1...  GT:AD:DP:GQ:PL
# 49574  AC=1;AF=0.500;AN=2;DP=22;ExcessHet=3.0103;FS=4...  GT:AD:DP:GQ:PL
# 49575  AC=1;AF=0.500;AN=2;DP=17;ExcessHet=3.0103;FS=3...  GT:AD:DP:GQ:PL
# 49576  AC=1;AF=0.500;AN=2;DP=19;ExcessHet=3.0103;FS=4...  GT:AD:DP:GQ:PL
# 49577  AC=1;AF=0.500;AN=2;DP=63;ExcessHet=3.0103;FS=0...  GT:AD:DP:GQ:PL
#
#                                   20
# 0                 1/1:0,2:2:6:90,6,0
# 1                 1/1:0,2:2:6:84,6,0
# 2            1/1:0,10:10:30:343,30,0
# 3                 1/1:0,2:2:6:81,6,0
# 4                 1/1:0,2:2:6:84,6,0
# 5              1/1:0,5:5:15:209,15,0
# 6              1/1:0,8:8:24:334,24,0
# 7              1/1:0,4:4:12:155,12,0
# 8                 1/1:0,1:1:3:42,3,0
# 9                 1/1:0,1:1:3:42,3,0
# 10               1/1:0,3:3:9:123,9,0
# 11                1/1:0,1:1:3:41,3,0
# 12                1/1:0,1:1:3:42,3,0
# 13                1/1:0,1:1:3:45,3,0
# 14                1/1:0,1:1:3:45,3,0
# 15             1/1:0,4:4:12:167,12,0
# 16             1/1:0,4:4:12:155,12,0
# 17             1/1:0,4:4:12:167,12,0
# 18               1/1:1,4:5:5:158,5,0
# 19             1/1:0,9:9:27:314,27,0
# 20         1/1:0,59:59:99:2368,177,0
# 21                1/1:0,1:1:3:45,3,0
# 22                1/1:0,1:1:3:45,3,0
# 23           1/1:0,16:16:48:639,48,0
# 24             1/1:0,6:6:18:231,18,0
# 25             1/1:0,4:4:12:162,12,0
# 26                1/1:0,2:2:6:90,6,0
# 27             1/1:0,4:4:12:135,12,0
# 28                1/1:0,1:1:3:42,3,0
# 29                1/1:0,2:2:6:83,6,0
# ...                              ...
# 49548      0/1:25,11:36:99:240,0,711
# 49549      0/1:74,11:85:93:93,0,2127
# 49550     0/1:48,11:59:99:163,0,1319
# 49551     0/1:34,14:48:99:365,0,1277
# 49552  0/1:327,43:370:99:506,0,11701
# 49553         0/1:9,2:11:57:57,0,367
# 49554         0/1:9,2:11:57:57,0,366
# 49555           0/1:2,2:4:49:69,0,49
# 49556        0/1:22,3:25:38:38,0,808
# 49557  0/1:389,36:425:99:193,0,14344
# 49558     0/1:30,11:41:99:324,0,1106
# 49559      0/1:55,9:64:99:160,0,2025
# 49560    0/1:93,13:106:99:225,0,3321
# 49561   0/1:67,46:113:99:1450,0,2147
# 49562  0/1:159,67:226:99:2306,0,6383
# 49563     0/1:42,11:53:99:301,0,1514
# 49564        0/1:13,3:16:77:77,0,483
# 49565      0/1:39,9:48:99:208,0,1385
# 49566        0/1:20,5:25:78:78,0,749
# 49567        0/1:26,4:30:77:77,0,996
# 49568      0/1:20,12:32:99:405,0,695
# 49569   0/1:127,18:145:99:290,0,4748
# 49570  0/1:516,52:568:99:384,0,18719
# 49571    0/1:119,11:130:70:70,0,4413
# 49572      0/1:18,4:22:99:786,0,1325
# 49573     0/1:18,20:38:99:785,0,1326
# 49574       0/1:16,6:22:99:172,0,602
# 49575       0/1:12,5:17:99:112,0,341
# 49576       0/1:14,5:19:99:152,0,516
# 49577      0/1:56,7:63:99:103,0,1978
#
# [49578 rows x 10 columns]
