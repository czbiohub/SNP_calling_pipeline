# %%
# script: create_runbatch_config
# authors: Olga Botvinnik & Lincoln Harris
# date: 10.3.18
#
# Trying to build the input file to give gatk_pipeline.rf (required for batch mode run)
# Lets see if we can get this working for some of Angela's cells

# %%
# try to get all of the run prefixes w/in nonImmune_bams_9.27
bucketPrefixes = 's3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/'
f = 'nonImmune_bams_9.27_prefixes.txt'
! aws s3 ls $bucketPrefixes > $f
! cat $f
# Out:
#                            PRE 170125/
#                            PRE 170202/
#                            PRE 170215/
#                            PRE 170504/
#                            PRE 170508/
#                            PRE 170510/
#                            PRE 171120_concat1/
#                            PRE 180226/
#                            PRE 180307/
#                            PRE 180319/
#                            PRE 180320/
#                            PRE 180405/
#                            PRE 180423/
#                            PRE 180516/
#                            PRE 180519/
#                            PRE 180601/
#                            PRE 180604/
#                            PRE 180711/
#                            PRE 180831/
#                            PRE 180911/
#                            PRE 181029/
#                            PRE 181120/
#                            PRE vcf/
#                            PRE vcf1/

# %%
# read run names into a dataframe
#     with pandas!!
import pandas as pd
pd.options.display.max_colwidth = 500 # module config? 

runs_df = pd.read_table(f, delim_whitespace=True, header=None, names=['is_prefix', 'run_name'])
runs_df
# Out:
#    is_prefix         run_name
# 0        PRE          170125/
# 1        PRE          170202/
# 2        PRE          170215/
# 3        PRE          170504/
# 4        PRE          170508/
# 5        PRE          170510/
# 6        PRE  171120_concat1/
# 7        PRE          180226/
# 8        PRE          180307/
# 9        PRE          180319/
# 10       PRE          180320/
# 11       PRE          180405/
# 12       PRE          180423/
# 13       PRE          180516/
# 14       PRE          180519/
# 15       PRE          180601/
# 16       PRE          180604/
# 17       PRE          180711/
# 18       PRE          180831/
# 19       PRE          180911/
# 20       PRE          181029/
# 21       PRE          181120/
# 22       PRE             vcf/
# 23       PRE            vcf1/

# %%
# can i add a full_path col? 
runs_df['full_path'] = 's3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/' + runs_df['run_name']
runs_df
# Out:
#    is_prefix         run_name  \
# 0        PRE          170125/
# 1        PRE          170202/
# 2        PRE          170215/
# 3        PRE          170504/
# 4        PRE          170508/
# 5        PRE          170510/
# 6        PRE  171120_concat1/
# 7        PRE          180226/
# 8        PRE          180307/
# 9        PRE          180319/
# 10       PRE          180320/
# 11       PRE          180405/
# 12       PRE          180423/
# 13       PRE          180516/
# 14       PRE          180519/
# 15       PRE          180601/
# 16       PRE          180604/
# 17       PRE          180711/
# 18       PRE          180831/
# 19       PRE          180911/
# 20       PRE          181029/
# 21       PRE          181120/
# 22       PRE             vcf/
# 23       PRE            vcf1/
#
#                                                                                   full_path
# 0           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170125/
# 1           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170202/
# 2           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170215/
# 3           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170504/
# 4           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170508/
# 5           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170510/
# 6   s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/171120_concat1/
# 7           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180226/
# 8           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180307/
# 9           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180319/
# 10          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180320/
# 11          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180405/
# 12          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180423/
# 13          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180516/
# 14          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180519/
# 15          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180601/
# 16          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180604/
# 17          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180711/
# 18          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180831/
# 19          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180911/
# 20          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/181029/
# 21          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/181120/
# 22             s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf/
# 23            s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/

# %%
# get rid of the vcf row
runs_df = runs_df.drop([22,23])
runs_df
# Out:
#    is_prefix         run_name  \
# 0        PRE          170125/
# 1        PRE          170202/
# 2        PRE          170215/
# 3        PRE          170504/
# 4        PRE          170508/
# 5        PRE          170510/
# 6        PRE  171120_concat1/
# 7        PRE          180226/
# 8        PRE          180307/
# 9        PRE          180319/
# 10       PRE          180320/
# 11       PRE          180405/
# 12       PRE          180423/
# 13       PRE          180516/
# 14       PRE          180519/
# 15       PRE          180601/
# 16       PRE          180604/
# 17       PRE          180711/
# 18       PRE          180831/
# 19       PRE          180911/
# 20       PRE          181029/
# 21       PRE          181120/
#
#                                                                                   full_path
# 0           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170125/
# 1           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170202/
# 2           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170215/
# 3           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170504/
# 4           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170508/
# 5           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170510/
# 6   s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/171120_concat1/
# 7           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180226/
# 8           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180307/
# 9           s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180319/
# 10          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180320/
# 11          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180405/
# 12          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180423/
# 13          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180516/
# 14          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180519/
# 15          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180601/
# 16          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180604/
# 17          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180711/
# 18          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180831/
# 19          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180911/
# 20          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/181029/
# 21          s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/181120/

# %%
# get all of the cells in a given run directory
prefix = 's3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/'
txt = 'runX_cells.txt'
! aws s3 ls $prefix > $txt
! cat $txt
# Out:
#                            PRE C3_1001000403/
#                            PRE E3_1001000362/
#                            PRE F1_1001000362/
#                            PRE G5_1001000362/
#                            PRE H1_1001000362/
#                            PRE H7_1001000377/
#                            PRE J11_1001000367/
#                            PRE L2_1001000362/
#                            PRE M10_1001000365/
#                            PRE M2_1001000413/
#                            PRE M3_1001000362/
#                            PRE N2_1001000380/
#                            PRE O23_1001000377/
#                            PRE O24_1001000377/
#                            PRE O7_B001797/

# %%
# read 180226 cell names into a dataframe
cells_df = pd.read_table(txt, delim_whitespace=True, header=None, names=['is_prefix', 'cell_name'])
cells_df
# Out:
#    is_prefix        cell_name
# 0        PRE   C3_1001000403/
# 1        PRE   E3_1001000362/
# 2        PRE   F1_1001000362/
# 3        PRE   G5_1001000362/
# 4        PRE   H1_1001000362/
# 5        PRE   H7_1001000377/
# 6        PRE  J11_1001000367/
# 7        PRE   L2_1001000362/
# 8        PRE  M10_1001000365/
# 9        PRE   M2_1001000413/
# 10       PRE   M3_1001000362/
# 11       PRE   N2_1001000380/
# 12       PRE  O23_1001000377/
# 13       PRE  O24_1001000377/
# 14       PRE      O7_B001797/

# %%
# ls one of our s3 cell directories
test_files = ! aws s3 ls $prefix\C3_1001000403/ # what does backslash do? 
test_files
# Out:
# ['2018-10-05 10:58:28   10894185 C3_1001000403.vcf',
#  '2018-09-28 17:55:52 1693079358 C3_1001000403_S123.homo.Aligned.out.sorted.bam',
#  '2018-09-28 17:57:43    2447520 C3_1001000403_S123.homo.Aligned.out.sorted.bam.bai']

# %%
# get full s3 paths for bam files, then add them to a new col in cells_df

def get_bam(cell):
    s3_location = f'{prefix}{cell}' #f? 
    lines = ! aws s3 ls $s3_location
    bam_line = [x for x in lines if x.endswith('bam')][0] # get the bam file, specifically
    bam_basename = bam_line.split()[-1]
    return f'{s3_location}{bam_basename}'


cells_df['input_bam'] = cells_df['cell_name'].map(get_bam) # applying function, and assigning output to new col in cells_df
cells_df.head()
# Out:
#   is_prefix       cell_name  \
# 0       PRE  C3_1001000403/
# 1       PRE  E3_1001000362/
# 2       PRE  F1_1001000362/
# 3       PRE  G5_1001000362/
# 4       PRE  H1_1001000362/
#
#                                                                                                                           input_bam
# 0  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403_S123.homo.Aligned.out.sorted.bam
# 1   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362_S99.homo.Aligned.out.sorted.bam
# 2  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362_S121.homo.Aligned.out.sorted.bam
# 3  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362_S149.homo.Aligned.out.sorted.bam
# 4  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362_S169.homo.Aligned.out.sorted.bam

# %%
# sanity check
cells_df['input_bam']
# Out:
# 0       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403_S123.homo.Aligned.out.sorted.bam
# 1        s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362_S99.homo.Aligned.out.sorted.bam
# 2       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362_S121.homo.Aligned.out.sorted.bam
# 3       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362_S149.homo.Aligned.out.sorted.bam
# 4       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362_S169.homo.Aligned.out.sorted.bam
# 5       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H7_1001000377/H7_1001000377_S295.homo.Aligned.out.sorted.bam
# 6     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/J11_1001000367/J11_1001000367_S179.homo.Aligned.out.sorted.bam
# 7       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/L2_1001000362/L2_1001000362_S266.homo.Aligned.out.sorted.bam
# 8     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M10_1001000365/M10_1001000365_S166.homo.Aligned.out.sorted.bam
# 9       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M2_1001000413/M2_1001000413_S230.homo.Aligned.out.sorted.bam
# 10      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M3_1001000362/M3_1001000362_S291.homo.Aligned.out.sorted.bam
# 11      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/N2_1001000380/N2_1001000380_S218.homo.Aligned.out.sorted.bam
# 12    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O23_1001000377/O23_1001000377_S179.homo.Aligned.out.sorted.bam
# 13    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O24_1001000377/O24_1001000377_S180.homo.Aligned.out.sorted.bam
# 14             s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O7_B001797/O7_B001797_S67.homo.Aligned.out.sorted.bam
# Name: input_bam, dtype: object

# %%
# add a sample_id col
cells_df['sample_id'] = cells_df.cell_name.str.strip('/') # getting rid of the forward slashes
cells_df.head()
# Out:
#   is_prefix       cell_name  \
# 0       PRE  C3_1001000403/
# 1       PRE  E3_1001000362/
# 2       PRE  F1_1001000362/
# 3       PRE  G5_1001000362/
# 4       PRE  H1_1001000362/
#
#                                                                                                                           input_bam  \
# 0  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403_S123.homo.Aligned.out.sorted.bam
# 1   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362_S99.homo.Aligned.out.sorted.bam
# 2  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362_S121.homo.Aligned.out.sorted.bam
# 3  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362_S149.homo.Aligned.out.sorted.bam
# 4  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362_S169.homo.Aligned.out.sorted.bam
#
#        sample_id             id
# 0  C3_1001000403  C3_1001000403
# 1  E3_1001000362  E3_1001000362
# 2  F1_1001000362  F1_1001000362
# 3  G5_1001000362  G5_1001000362
# 4  H1_1001000362  H1_1001000362

# %%
# building the output vcf string
import os

cells_df['output_prefix'] = cells_df['input_bam'].map(os.path.dirname)
cells_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2e634306c25a> in <module>()
#       2 import os
#       3
# ----> 4 cells_df['output_prefix'] = cells_df['input_bam'].map(os.path.dirname)
#       5 cells_df.head()
#
# NameError: name 'cells_df' is not defined

# %%
# building the output vcf string
cells_df['output_vcf'] = cells_df.apply( # not sure how this works
    lambda x: '{output_prefix}/{sample_id}.vcf'.format(**x), axis=1)
cells_df.head()
# Out:
#   is_prefix       cell_name  \
# 0       PRE  C3_1001000403/
# 1       PRE  E3_1001000362/
# 2       PRE  F1_1001000362/
# 3       PRE  G5_1001000362/
# 4       PRE  H1_1001000362/
#
#                                                                                                                           input_bam  \
# 0  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403_S123.homo.Aligned.out.sorted.bam
# 1   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362_S99.homo.Aligned.out.sorted.bam
# 2  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362_S121.homo.Aligned.out.sorted.bam
# 3  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362_S149.homo.Aligned.out.sorted.bam
# 4  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362_S169.homo.Aligned.out.sorted.bam
#
#        sample_id             id  \
# 0  C3_1001000403  C3_1001000403
# 1  E3_1001000362  E3_1001000362
# 2  F1_1001000362  F1_1001000362
# 3  G5_1001000362  G5_1001000362
# 4  H1_1001000362  H1_1001000362
#
#                                                                        output_prefix  \
# 0  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403
# 1  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362
# 2  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362
# 3  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362
# 4  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362
#
#                                                                                             output_vcf
# 0  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403.vcf
# 1  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362.vcf
# 2  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362.vcf
# 3  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362.vcf
# 4  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362.vcf

# %%
# subset cells_df by only what we want
cols_to_keep = ['input_bam', 'sample_id', 'output_vcf']

samples_df = cells_df[cols_to_keep]
samples_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-29974e103a69> in <module>()
#       2 cols_to_keep = ['input_bam', 'sample_id', 'output_vcf']
#       3
# ----> 4 samples_df = cells_df[cols_to_keep]
#       5 samples_df
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['sample_id' 'output_vcf'] not in index"

# %%
# writeFunc()
#     write this guy to a file
#def writeFunc():
import json

out_dir = '../gatk/11.29.18_redo'

# write samples_df to file
! mkdir -p $out_dir
big_df.to_csv(f'{out_dir}/samples.csv', index=False)

# write a config file
config =     {
    "program": "../../reflow/gatk_pipeline.rf",
    "runs_file": "samples.csv"
}

with open(f'{out_dir}/config.json', 'w') as f:
    json.dump(config, f)
    
! head -n 3 $out_dir/samples.csv $out_dir/config.json
# Out:
# ==> ../gatk/11.29.18_redo/samples.csv <==
# id,input_bam,sample_id,output_vcf
# G12_1001000292,s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170125/G12_1001000292/G12_1001000292_S72.homo.Aligned.out.sorted.bam,G12_1001000292,s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/G12_1001000292.vcf
# H2_1001000293,s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170125/H2_1001000293/H2_1001000293_S144.homo.Aligned.out.sorted.bam,H2_1001000293,s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/H2_1001000293.vcf
#
# ==> ../gatk/11.29.18_redo/config.json <==
# {"program": "../../reflow/gatk_pipeline.rf", "runs_file": "samples.csv"}

# %%
## can we make a function or a class to do everything we just did? 

# get_bam()
#     gets full paths to bam files
def get_bam(cell):
    s3_location = f'{prefix}{cell}' #f? 
    lines = ! aws s3 ls $s3_location
    bam_line = [x for x in lines if x.endswith('bam')][0] # get the bam file, specifically
    bam_basename = bam_line.split()[-1]
    return f'{s3_location}{bam_basename}'

# driver()
#     Gets cell names given a prefix, and sets up dataframe
def driver(prefix): 
    #print("in driver")
    txt = 'runX_cells.txt'
    ! aws s3 ls $prefix > $txt
    
    # read into a pandas dataframe
    cells_df = pd.read_table(txt, delim_whitespace=True, header=None, names=['is_prefix', 'cell_name'])

    # call get_bam() and add 'input_bam' col
    cells_df['input_bam'] = cells_df['cell_name'].map(get_bam) # how does this map thing work? 
    
    # get rid of forward slashes and add 'sample_id' col
    cells_df['sample_id'] = cells_df.cell_name.str.strip('/')
    
    # add output_prefix col
    cells_df['output_vcf'] = 's3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/' + cells_df['sample_id'] + '.vcf'               
    
    # subset cells_df by only what we want
    cols_to_keep = ['input_bam', 'sample_id', 'output_vcf']
    samples_df = cells_df[cols_to_keep]
    
    return(samples_df)

# %%
# call this our Main() i guess
#       run driver function

big_df = pd.DataFrame() # init empty dataframe

for i in range(0, len(runs_df.index)-2):
    global prefix # dont like this
    prefix = runs_df['full_path'][i]
    print(prefix)
    curr_df = driver(prefix)
    toConcat = [big_df, curr_df]
    big_df = pd.concat(toConcat)
# Out:
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170125/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170202/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170215/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170504/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170508/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170510/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/171120_concat1/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180226/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180307/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180319/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180320/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180405/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180423/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180516/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180519/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180601/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180604/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180711/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180831/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/180911/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/181029/
# s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/181120/
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-901c888b8444> in <module>()
#       8     prefix = runs_df['full_path'][i]
#       9     print(prefix)
# ---> 10     curr_df = driver(prefix)
#      11     toConcat = [big_df, curr_df]
#      12     big_df = pd.concat(toConcat)
#
# <ipython-input-10-1ffbda5d03f0> in driver(prefix)
#      21
#      22     # call get_bam() and add 'input_bam' col
# ---> 23     cells_df['input_bam'] = cells_df['cell_name'].map(get_bam) # how does this map thing work?
#      24
#      25     # get rid of forward slashes and add 'sample_id' col
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2156         else:
#    2157             # arg is a function
# -> 2158             new_values = map_f(values, arg)
#    2159
#    2160         return self._constructor(new_values,
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-10-1ffbda5d03f0> in get_bam(cell)
#       6     s3_location = f'{prefix}{cell}' #f?
#       7     lines = get_ipython().getoutput('aws s3 ls $s3_location')
# ----> 8     bam_line = [x for x in lines if x.endswith('bam')][0] # get the bam file, specifically
#       9     bam_basename = bam_line.split()[-1]
#      10     return f'{s3_location}{bam_basename}'
#
# IndexError: list index out of range

# %%
big_df.head()
# Out:
#                                                                                                                                       input_bam  \
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170125/G12_1001000292/G12_1001000292_S72.homo.Aligned.out.sorted.bam
# 1   s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170125/H2_1001000293/H2_1001000293_S144.homo.Aligned.out.sorted.bam
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170202/G12_1001000292/G12_1001000292_S51.homo.Aligned.out.sorted.bam
# 0   s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170215/B10_1001000301/B10_1001000301_S7.homo.Aligned.out.sorted.bam
# 1  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170215/B10_1001000302/B10_1001000302_S45.homo.Aligned.out.sorted.bam
#
#         sample_id  \
# 0  G12_1001000292
# 1   H2_1001000293
# 0  G12_1001000292
# 0  B10_1001000301
# 1  B10_1001000302
#
#                                                                                         output_vcf
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/G12_1001000292.vcf
# 1   s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/H2_1001000293.vcf
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/G12_1001000292.vcf
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/B10_1001000301.vcf
# 1  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/B10_1001000302.vcf

# %%
len(big_df.index)
# Out:
# 8262

# %%
# add id col? 
big_df["id"] = big_df["sample_id"]
big_df.head()
# Out:
#                                                                                                                                       input_bam  \
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170125/G12_1001000292/G12_1001000292_S72.homo.Aligned.out.sorted.bam
# 1   s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170125/H2_1001000293/H2_1001000293_S144.homo.Aligned.out.sorted.bam
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170202/G12_1001000292/G12_1001000292_S51.homo.Aligned.out.sorted.bam
# 0   s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170215/B10_1001000301/B10_1001000301_S7.homo.Aligned.out.sorted.bam
# 1  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170215/B10_1001000302/B10_1001000302_S45.homo.Aligned.out.sorted.bam
#
#         sample_id  \
# 0  G12_1001000292
# 1   H2_1001000293
# 0  G12_1001000292
# 0  B10_1001000301
# 1  B10_1001000302
#
#                                                                                         output_vcf  \
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/G12_1001000292.vcf
# 1   s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/H2_1001000293.vcf
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/G12_1001000292.vcf
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/B10_1001000301.vcf
# 1  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/B10_1001000302.vcf
#
#                id
# 0  G12_1001000292
# 1   H2_1001000293
# 0  G12_1001000292
# 0  B10_1001000301
# 1  B10_1001000302

# %%
# need to fix col order
big_df = big_df[['id', 'input_bam', 'sample_id', 'output_vcf']]
big_df.head()
# Out:
#                id  \
# 0  G12_1001000292
# 1   H2_1001000293
# 0  G12_1001000292
# 0  B10_1001000301
# 1  B10_1001000302
#
#                                                                                                                                       input_bam  \
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170125/G12_1001000292/G12_1001000292_S72.homo.Aligned.out.sorted.bam
# 1   s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170125/H2_1001000293/H2_1001000293_S144.homo.Aligned.out.sorted.bam
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170202/G12_1001000292/G12_1001000292_S51.homo.Aligned.out.sorted.bam
# 0   s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170215/B10_1001000301/B10_1001000301_S7.homo.Aligned.out.sorted.bam
# 1  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/170215/B10_1001000302/B10_1001000302_S45.homo.Aligned.out.sorted.bam
#
#         sample_id  \
# 0  G12_1001000292
# 1   H2_1001000293
# 0  G12_1001000292
# 0  B10_1001000301
# 1  B10_1001000302
#
#                                                                                         output_vcf
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/G12_1001000292.vcf
# 1   s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/H2_1001000293.vcf
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/G12_1001000292.vcf
# 0  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/B10_1001000301.vcf
# 1  s3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_bams_9.27/vcf1/B10_1001000302.vcf

# %%
# messing around
import pandas as pd
database = pd.read_csv("/Users/lincoln.harris/Desktop/CosmicGenomeScreensMutantExport.tsv", delimiter = '\t')
database.head()
# Out:
#                         Gene name Accession Number  Gene CDS length HGNC ID  \
# 0                            TRIO  ENST00000344204             9294   12303
# 1           ABCC4_ENST00000376887  ENST00000376887             3978     NaN
# 2            TP53_ENST00000413465  ENST00000413465              858   11998
# 3                            EXD3  ENST00000340951             2274   26023
# 4                           ELMO2  ENST00000396391             2163   17233
# 5        C6orf165_ENST00000369562  ENST00000369562             1869     NaN
# 6                            LYST  ENST00000389793            11406    1968
# 7            TP53_ENST00000269305  ENST00000269305             1182     NaN
# 8                         APBB1IP  ENST00000376236             2001   17379
# 9            MKS1_ENST00000337050  ENST00000337050             1566    7121
# 10                           ACO1  ENST00000309951             2670     117
# 11            DST_ENST00000370765  ENST00000370765             7950     NaN
# 12                       ADAMTS12  ENST00000504830             4785   14605
# 13            MCC_ENST00000408903  ENST00000408903             3060    6935
# 14                       KIAA0746  ENST00000399878             2940   29108
# 15                         SEPT10  ENST00000397714             1296   14349
# 16                         PTCHD3  ENST00000438700             2304   24776
# 17                           SDHA  ENST00000264932             1995   10680
# 18                            BTK  ENST00000308731             1980    1133
# 19           JAG1_ENST00000254958  ENST00000254958             3657     NaN
# 20                          PRDM9  ENST00000296682             2685   13994
# 21                           LRP1  ENST00000243077            13635    6692
# 22                          SPTA1  ENST00000368148             7260     NaN
# 23           MLL3_ENST00000355193  ENST00000355193            14907   13726
# 24                         ABCA13  ENST00000319379            15012     NaN
# 25                         CAMKK2  ENST00000324774             1767    1470
# 26                        FAM75D4  ENST00000344803             4731   37283
# 27                        PIK3AP1  ENST00000339364             2418   30034
# 28                         OR2AE1  ENST00000316368              972   15087
# 29                          ACACB  ENST00000377848             7377      85
# ...                           ...              ...              ...     ...
# 5925510       TTN_ENST00000356127  ENST00000356127           100266     NaN
# 5925511   RUNX1T1_ENST00000265814  ENST00000265814             1815    1535
# 5925512                      POLQ      NM_006596.3             8178    9186
# 5925513                     ATXN2  ENST00000377617             3942   10555
# 5925514                     KIF4B  ENST00000435029             3705    6322
# 5925515     SYNE1_ENST00000423061  ENST00000423061            26250   17089
# 5925516      TP53_ENST00000545858  ENST00000545858              465     NaN
# 5925517       TTN_ENST00000342175  ENST00000342175            81357   12403
# 5925518    PCDH20_ENST00000409186  ENST00000409186             2856   14257
# 5925519     EP400_ENST00000333577  ENST00000333577             9480   11958
# 5925520   ARHGEF7_ENST00000544132  ENST00000544132              546   15607
# 5925521     PRSS3_ENST00000361005  ENST00000361005              915    9486
# 5925522                     OR2T6  ENST00000355728              927   15018
# 5925523                   CACNA1H  ENST00000358590             7044    1395
# 5925524                      BMP5  ENST00000370830             1365    1072
# 5925525                     KNDC1  ENST00000304613             5250   29374
# 5925526   AADACL3_ENST00000359318  ENST00000359318             1053   32037
# 5925527                     ACSF2  ENST00000300441             1848   26101
# 5925528                    MAGEC3  ENST00000298296             1932   23798
# 5925529                     PPIL4  ENST00000253329             1479   15702
# 5925530                   TCERG1L  ENST00000368643             1638     NaN
# 5925531     ASTN1_ENST00000367654  ENST00000367654             3909     773
# 5925532                    GPR124  ENST00000412232             4017   17849
# 5925533                  PCDHGA12  ENST00000252085             2799    8699
# 5925534                    FTSJD2  ENST00000373451             2508   21077
# 5925535                   NDUFA13      NM_015965.3              684   17194
# 5925536       TTN_ENST00000342992  ENST00000342992           100272   12403
# 5925537    RHBDF1_ENST00000454039  ENST00000454039             1740   20561
# 5925538    TRIM10_ENST00000376704  ENST00000376704             1188   10072
# 5925539   COL18A1_ENST00000359759  ENST00000359759             5265    2195
#
#                Sample name  ID_sample  ID_tumour  \
# 0                  MZ7-mel     753596     672566
# 1                 05-165K5    2575184    2436521
# 2                 PD11327a    1744637    1649978
# 3            HUB-02-C2-098    2607142    2466854
# 4            HUB-02-B2-113    2607139    2466851
# 5                     LOVO    2301996    2167279
# 6          TCGA-05-4427-01    1780073    1684072
# 7          TCGA-EE-A29M-06    2121640    1995876
# 8                  LAU50_2    1675357    1588296
# 9                 P04-2599    1691461    1599728
# 10                B5-Tumor    2186176    2054473
# 11         TCGA-AG-A002-01    1651648    1566435
# 12                  MD-275    1735394    1641338
# 13         TCGA-AA-A00N-01    1651102    1565889
# 14         TCGA-AG-A002-01    1651648    1566435
# 15         TCGA-AG-A002-01    1651648    1566435
# 16                   T3502    2658524    2518683
# 17         TCGA-AA-3672-01    1651015    1565802
# 18                  S01728    2480858    2343603
# 19         TCGA-BR-4292-01    2197923    2066201
# 20                  S00539    2480815    2343560
# 21             LUAD-B02477    1765175    1669495
# 22             LUAD-F00121    1765206    1669526
# 23             LUAD-E00897    1765243    1669563
# 24       LUAD-CHTN-3090415    1765197    1669517
# 25             LUAD-S01356    1765097    1669417
# 26             LUAD-S01304    1765165    1669485
# 27          LUAD-RT-S01818    1765224    1669544
# 28               CSCC-60-T    2292492    2158556
# 29         TCGA-BH-A0E9-01    1899927    1788611
# ...                    ...        ...        ...
# 5925510    TCGA-GN-A265-06    2121795    1996031
# 5925511           CHC1601T    2340178    2205161
# 5925512  2014_Lung_sq_56_T    2744927    2603630
# 5925513              PD_01    2688657    2547639
# 5925514             587222    1766748    1671068
# 5925515    TCGA-32-1982-01    1338091    1248476
# 5925516          ESCC-162T    2186058    2054355
# 5925517               HT29    2301988    2167271
# 5925518      CHG-13-12016T    2634314    2494710
# 5925519           UD-SCC-2    2296311    2161914
# 5925520          WGC067107    2549364    2410819
# 5925521            2292383    2292383    2158447
# 5925522       3N40-VS-3T40    2363607    2226534
# 5925523           1517_CLM    2501001    2363352
# 5925524                D28    2465280    2328113
# 5925525               T354    2658281    2518440
# 5925526             ME029T    1673894    1586950
# 5925527            ESCC_14    2479525    2342285
# 5925528          ESCC-158T    2186051    2054348
# 5925529    TCGA-FV-A2QR-01    2194663    2062941
# 5925530            CRC-08T    2456775    2319612
# 5925531                D15    2368352    2231156
# 5925532             S02351    2480911    2343656
# 5925533    TCGA-BR-8680-01    2197966    2066244
# 5925534            1946219    1946219    1833129
# 5925535    TCGA-F4-6570-01    1651303    1566090
# 5925536            2521259    2521259    2383602
# 5925537             A12-2A    2746130    2604833
# 5925538             BD217T    2459849    2322686
# 5925539               D36T    2745023    2603726
#
#                                Primary site          Site subtype 1  \
# 0                                      skin                      NS
# 1                                  prostate                      NS
# 2                                    breast                      NS
# 3                           large_intestine                      NS
# 4                           large_intestine                      NS
# 5                           large_intestine                      NS
# 6                                      lung                      NS
# 7                                      skin                      NS
# 8                                      skin                     leg
# 9                                  prostate                      NS
# 10                            urinary_tract                 bladder
# 11                          large_intestine                  rectum
# 12                   central_nervous_system                   brain
# 13                          large_intestine                  caecum
# 14                          large_intestine                  rectum
# 15                          large_intestine                  rectum
# 16                          large_intestine                      NS
# 17                          large_intestine                   colon
# 18                                     lung                      NS
# 19                                  stomach                      NS
# 20                                     lung                      NS
# 21                                     lung                      NS
# 22                                     lung                      NS
# 23                                     lung                      NS
# 24                                     lung                      NS
# 25                                     lung                      NS
# 26                                     lung                      NS
# 27                                     lung                      NS
# 28                                     skin               head_neck
# 29                                   breast                      NS
# ...                                     ...                     ...
# 5925510                                skin                      NS
# 5925511                               liver                      NS
# 5925512                                lung                      NS
# 5925513                                skin                shoulder
# 5925514                     large_intestine                   colon
# 5925515              central_nervous_system                   brain
# 5925516                          oesophagus                      NS
# 5925517                     large_intestine                   colon
# 5925518                               liver                      NS
# 5925519           upper_aerodigestive_tract               head_neck
# 5925520                     large_intestine                      NS
# 5925521  haematopoietic_and_lymphoid_tissue  central_nervous_system
# 5925522                          oesophagus                      NS
# 5925523                     large_intestine                   colon
# 5925524                                  NS                      NS
# 5925525                     large_intestine                      NS
# 5925526                                skin                   trunk
# 5925527                          oesophagus                      NS
# 5925528                          oesophagus                      NS
# 5925529                               liver                      NS
# 5925530                     large_intestine                      NS
# 5925531                     large_intestine                      NS
# 5925532                                lung                      NS
# 5925533                             stomach                      NS
# 5925534                                lung                      NS
# 5925535                     large_intestine                   colon
# 5925536                                skin                    face
# 5925537                     large_intestine                      NS
# 5925538                       biliary_tract               bile_duct
# 5925539                             thyroid                      NS
#
#         Site subtype 2  ...   Mutation strand  SNP FATHMM prediction  \
# 0                   NS  ...                 +    n        PATHOGENIC
# 1                   NS  ...                 -  NaN               NaN
# 2                   NS  ...                 -    n        PATHOGENIC
# 3                   NS  ...                 -    n           NEUTRAL
# 4                   NS  ...                 -    n           NEUTRAL
# 5                   NS  ...                 +    n        PATHOGENIC
# 6                   NS  ...                 -    n        PATHOGENIC
# 7                   NS  ...                 -    n        PATHOGENIC
# 8                   NS  ...                 +    y        PATHOGENIC
# 9                   NS  ...                 -    n        PATHOGENIC
# 10                  NS  ...                 +    n        PATHOGENIC
# 11                  NS  ...                 -    n        PATHOGENIC
# 12                  NS  ...                 -    n           NEUTRAL
# 13                  NS  ...                 -    n        PATHOGENIC
# 14                  NS  ...                 -    n        PATHOGENIC
# 15                  NS  ...                 -    n        PATHOGENIC
# 16                  NS  ...                 -    n           NEUTRAL
# 17          transverse  ...                 +    n        PATHOGENIC
# 18                  NS  ...                 -    n        PATHOGENIC
# 19                  NS  ...                 -    n               NaN
# 20                  NS  ...                 +    n           NEUTRAL
# 21                  NS  ...                 +    n           NEUTRAL
# 22                  NS  ...                 -    n        PATHOGENIC
# 23                  NS  ...                 -    n        PATHOGENIC
# 24                  NS  ...                 +    n        PATHOGENIC
# 25                  NS  ...                 -    n        PATHOGENIC
# 26                  NS  ...                 +    n           NEUTRAL
# 27                  NS  ...                 -    n        PATHOGENIC
# 28                  NS  ...                 -    n           NEUTRAL
# 29                  NS  ...                 +    n        PATHOGENIC
# ...                ...  ...               ...  ...               ...
# 5925510             NS  ...                 -    n        PATHOGENIC
# 5925511             NS  ...                 -    n        PATHOGENIC
# 5925512             NS  ...                 -    n        PATHOGENIC
# 5925513             NS  ...                 -    n        PATHOGENIC
# 5925514             NS  ...                 +    n           NEUTRAL
# 5925515             NS  ...                 -    n        PATHOGENIC
# 5925516             NS  ...                 -    n        PATHOGENIC
# 5925517           left  ...                 -    n               NaN
# 5925518             NS  ...                 -    n        PATHOGENIC
# 5925519             NS  ...                 +  NaN               NaN
# 5925520             NS  ...                 +    n        PATHOGENIC
# 5925521             NS  ...                 +    n           NEUTRAL
# 5925522             NS  ...                 +    y           NEUTRAL
# 5925523          right  ...                 +    n        PATHOGENIC
# 5925524             NS  ...                 -    n        PATHOGENIC
# 5925525             NS  ...                 +    n        PATHOGENIC
# 5925526             NS  ...                 +    n           NEUTRAL
# 5925527             NS  ...                 +    n        PATHOGENIC
# 5925528             NS  ...                 +    n           NEUTRAL
# 5925529             NS  ...                 -    n           NEUTRAL
# 5925530             NS  ...                 -    n        PATHOGENIC
# 5925531             NS  ...                 -    n        PATHOGENIC
# 5925532             NS  ...                 +    n        PATHOGENIC
# 5925533             NS  ...                 +    n           NEUTRAL
# 5925534             NS  ...                 +    n        PATHOGENIC
# 5925535     transverse  ...                 +    n        PATHOGENIC
# 5925536             NS  ...                 -    n        PATHOGENIC
# 5925537             NS  ...                 -  NaN               NaN
# 5925538             NS  ...                 -    n        PATHOGENIC
# 5925539             NS  ...                 +    n           NEUTRAL
#
#         FATHMM score                       Mutation somatic status  \
# 0            0.98488                     Confirmed somatic variant
# 1                NaN                     Confirmed somatic variant
# 2            0.99623                     Confirmed somatic variant
# 3            0.02736                     Confirmed somatic variant
# 4            0.22837                     Confirmed somatic variant
# 5            0.96754                     Variant of unknown origin
# 6            0.93522                     Variant of unknown origin
# 7            0.99744                     Confirmed somatic variant
# 8            0.83812                     Variant of unknown origin
# 9            0.87460                     Variant of unknown origin
# 10           0.92305                     Confirmed somatic variant
# 11           0.93493                     Confirmed somatic variant
# 12           0.33337                     Confirmed somatic variant
# 13           0.80500                     Confirmed somatic variant
# 14           0.81702                     Confirmed somatic variant
# 15           0.98264                     Confirmed somatic variant
# 16           0.03050                     Confirmed somatic variant
# 17           0.92179                     Confirmed somatic variant
# 18           0.71271                     Confirmed somatic variant
# 19           0.50652                     Confirmed somatic variant
# 20           0.00506                     Confirmed somatic variant
# 21           0.01660                     Variant of unknown origin
# 22           0.95960                     Variant of unknown origin
# 23           0.98145  Reported in another cancer sample as somatic
# 24           0.87482                     Variant of unknown origin
# 25           0.96803                     Variant of unknown origin
# 26           0.00397                     Variant of unknown origin
# 27           0.96383                     Variant of unknown origin
# 28           0.25050                     Confirmed somatic variant
# 29           0.97454                     Confirmed somatic variant
# ...              ...                                           ...
# 5925510      0.98624                     Confirmed somatic variant
# 5925511      0.98085                     Confirmed somatic variant
# 5925512      0.98771                     Confirmed somatic variant
# 5925513      0.99503                     Confirmed somatic variant
# 5925514      0.09294                     Variant of unknown origin
# 5925515      0.95014                     Confirmed somatic variant
# 5925516      0.99190                     Confirmed somatic variant
# 5925517      0.65918                     Variant of unknown origin
# 5925518      0.96639                     Confirmed somatic variant
# 5925519          NaN                     Variant of unknown origin
# 5925520      0.78033                     Confirmed somatic variant
# 5925521      0.11283                     Confirmed somatic variant
# 5925522      0.00876                     Confirmed somatic variant
# 5925523      0.96854                     Confirmed somatic variant
# 5925524      0.99066                     Confirmed somatic variant
# 5925525      0.77978                     Confirmed somatic variant
# 5925526      0.05860                     Variant of unknown origin
# 5925527      0.92875                     Confirmed somatic variant
# 5925528      0.00338                     Confirmed somatic variant
# 5925529      0.00896                     Confirmed somatic variant
# 5925530      0.96520                     Confirmed somatic variant
# 5925531      0.97512                     Confirmed somatic variant
# 5925532      0.99181                     Confirmed somatic variant
# 5925533      0.37951                     Confirmed somatic variant
# 5925534      0.97269                     Confirmed somatic variant
# 5925535      0.85538                     Confirmed somatic variant
# 5925536      0.99517                     Confirmed somatic variant
# 5925537          NaN                     Confirmed somatic variant
# 5925538      0.92305                     Confirmed somatic variant
# 5925539      0.01237                     Confirmed somatic variant
#
#         Pubmed_PMID ID_STUDY           Sample Type Tumour origin    Age
# 0               NaN     30.0             cell-line    metastasis    NaN
# 1        26928463.0      NaN         autopsy - NOS    metastasis  69.00
# 2               NaN    652.0                    NS            NS    NaN
# 3               NaN    670.0      organoid culture            NS    NaN
# 4               NaN    670.0      organoid culture            NS    NaN
# 5        24755471.0      NaN             cell-line            NS    NaN
# 6               NaN    417.0    fresh/frozen - NOS       primary  65.00
# 7               NaN    540.0                    NS            NS  33.00
# 8        22197931.0      NaN             cell-line    metastasis    NaN
# 9        22610119.0      NaN  surgery fresh/frozen       primary  68.00
# 10              NaN    581.0                    NS            NS    NaN
# 11       22810696.0    375.0                    NS       primary  35.00
# 12       22820256.0      NaN         surgery - NOS       primary    NaN
# 13       22810696.0    376.0                    NS            NS  75.00
# 14       22810696.0    375.0                    NS       primary  35.00
# 15       22810696.0    375.0                    NS       primary  35.00
# 16       27149842.0      NaN                    NS            NS  78.16
# 17       22810696.0    376.0                    NS            NS  90.00
# 18       26168399.0      NaN  surgery fresh/frozen       primary  65.00
# 19              NaN    541.0                    NS            NS  73.00
# 20       26168399.0      NaN  autopsy-fresh/frozen       primary  66.00
# 21       22980975.0      NaN         surgery - NOS       primary  77.00
# 22       22980975.0      NaN         surgery - NOS       primary  66.00
# 23       22980975.0      NaN         surgery - NOS       primary  58.00
# 24       22980975.0      NaN         surgery - NOS       primary  56.00
# 25       22980975.0      NaN         surgery - NOS       primary  80.00
# 26       22980975.0      NaN         surgery - NOS       primary  75.00
# 27       22980975.0      NaN         surgery - NOS       primary    NaN
# 28       25303977.0      NaN  surgery fresh/frozen       primary  64.00
# 29              NaN    414.0    fresh/frozen - NOS       primary  53.00
# ...             ...      ...                   ...           ...    ...
# 5925510         NaN    540.0                    NS            NS  53.00
# 5925511         NaN    381.0                    NS       primary  75.00
# 5925512         NaN    583.0                    NS       primary  67.00
# 5925513  24662767.0      NaN  surgery fresh/frozen            NS  71.00
# 5925514  22895193.0      NaN  surgery fresh/frozen       primary    NaN
# 5925515         NaN    329.0  surgery fresh/frozen            NS  76.00
# 5925516         NaN    582.0                    NS            NS    NaN
# 5925517  24755471.0      NaN             cell-line            NS    NaN
# 5925518         NaN    660.0                    NS       primary  77.00
# 5925519  25275298.0      NaN             cell-line            NS  58.00
# 5925520         NaN    646.0                    NS       primary  38.00
# 5925521  24970810.0      NaN  surgery fresh/frozen            NS    NaN
# 5925522  25839328.0      NaN                    NS            NS  67.00
# 5925523  26109429.0      NaN    fresh/frozen - NOS    metastasis  37.00
# 5925524  23890154.0      NaN             cell-line    metastasis    NaN
# 5925525  27149842.0      NaN                    NS            NS  63.91
# 5925526  22622578.0      NaN         surgery - NOS    metastasis  51.00
# 5925527  26873401.0      NaN                    NS            NS  58.00
# 5925528         NaN    582.0                    NS            NS    NaN
# 5925529         NaN    628.0                    NS            NS  75.00
# 5925530         NaN    646.0                    NS       primary  58.00
# 5925531  24951259.0      NaN    fresh/frozen - NOS       primary    NaN
# 5925532  26168399.0      NaN  surgery fresh/frozen       primary  57.00
# 5925533         NaN    541.0                    NS            NS  45.00
# 5925534  20505728.0      NaN    fresh/frozen - NOS            NS  51.00
# 5925535  22810696.0    376.0                    NS            NS  78.00
# 5925536  25759019.0      NaN  surgery fresh/frozen     recurrent    NaN
# 5925537         NaN    646.0                    NS       primary  38.00
# 5925538         NaN    658.0                    NS       primary  52.00
# 5925539         NaN    676.0                    NS       primary  35.00
#
# [5925540 rows x 34 columns]

# %%
list(database)
# Out:
# ['Gene name',
#  'Accession Number',
#  'Gene CDS length',
#  'HGNC ID',
#  'Sample name',
#  'ID_sample',
#  'ID_tumour',
#  'Primary site',
#  'Site subtype 1',
#  'Site subtype 2',
#  'Site subtype 3',
#  'Primary histology',
#  'Histology subtype 1',
#  'Histology subtype 2',
#  'Histology subtype 3',
#  'Genome-wide screen',
#  'Mutation ID',
#  'Mutation CDS',
#  'Mutation AA',
#  'Mutation Description',
#  'Mutation zygosity',
#  'LOH',
#  'GRCh',
#  'Mutation genome position',
#  'Mutation strand',
#  'SNP',
#  'FATHMM prediction',
#  'FATHMM score',
#  'Mutation somatic status',
#  'Pubmed_PMID',
#  'ID_STUDY',
#  'Sample Type',
#  'Tumour origin',
#  'Age']

# %%
database.head()
# Out:
#                Gene name Accession Number  Gene CDS length HGNC ID  \
# 0                   TRIO  ENST00000344204             9294   12303
# 1  ABCC4_ENST00000376887  ENST00000376887             3978     NaN
# 2   TP53_ENST00000413465  ENST00000413465              858   11998
# 3                   EXD3  ENST00000340951             2274   26023
# 4                  ELMO2  ENST00000396391             2163   17233
#
#      Sample name  ID_sample  ID_tumour     Primary site Site subtype 1  \
# 0        MZ7-mel     753596     672566             skin             NS
# 1       05-165K5    2575184    2436521         prostate             NS
# 2       PD11327a    1744637    1649978           breast             NS
# 3  HUB-02-C2-098    2607142    2466854  large_intestine             NS
# 4  HUB-02-B2-113    2607139    2466851  large_intestine             NS
#
#   Site subtype 2  ...  Mutation strand  SNP FATHMM prediction FATHMM score  \
# 0             NS  ...                +    n        PATHOGENIC      0.98488
# 1             NS  ...                -  NaN               NaN          NaN
# 2             NS  ...                -    n        PATHOGENIC      0.99623
# 3             NS  ...                -    n           NEUTRAL      0.02736
# 4             NS  ...                -    n           NEUTRAL      0.22837
#
#      Mutation somatic status Pubmed_PMID ID_STUDY       Sample Type  \
# 0  Confirmed somatic variant         NaN     30.0         cell-line
# 1  Confirmed somatic variant  26928463.0      NaN     autopsy - NOS
# 2  Confirmed somatic variant         NaN    652.0                NS
# 3  Confirmed somatic variant         NaN    670.0  organoid culture
# 4  Confirmed somatic variant         NaN    670.0  organoid culture
#
#   Tumour origin   Age
# 0    metastasis   NaN
# 1    metastasis  69.0
# 2            NS   NaN
# 3            NS   NaN
# 4            NS   NaN
#
# [5 rows x 34 columns]

# %%
#database.loc[['Carcinoma'], ['Primary histology']]
#database.loc[['TRIO'], ['ID_sample']]
#database.where('TRIO', database)

#database['Primary histology'] == 'carcinoma'
#database['Primary site'] == 'lung'

pHistList = database.index[database['Primary histology'] == 'carcinoma'].tolist()
pSiteList = database.index[database['Primary site'] == 'lung'].tolist()

shared = list(set(pHistList) & set(pSiteList))
shared
# Out:
# [1048577,
#  1048580,
#  6,
#  2097159,
#  3145737,
#  3145738,
#  3145739,
#  2097166,
#  3145744,
#  18,
#  20,
#  21,
#  22,
#  23,
#  24,
#  25,
#  26,
#  27,
#  1048598,
#  1048601,
#  1048606,
#  1048607,
#  32,
#  1048608,
#  34,
#  35,
#  2097184,
#  37,
#  38,
#  3145764,
#  40,
#  41,
#  2097193,
#  43,
#  44,
#  45,
#  3145773,
#  4194348,
#  4194349,
#  5242929,
#  4194355,
#  5242931,
#  2097206,
#  1048631,
#  2097207,
#  57,
#  2097211,
#  3145787,
#  4194366,
#  3145793,
#  66,
#  67,
#  2097220,
#  4194371,
#  4194372,
#  2097223,
#  4194373,
#  5242947,
#  5242951,
#  2097227,
#  76,
#  1048652,
#  4194381,
#  5242952,
#  1048663,
#  3145816,
#  5242969,
#  2097243,
#  1048668,
#  4194396,
#  1048671,
#  5242977,
#  4194405,
#  3145835,
#  1048687,
#  5242993,
#  5242996,
#  4194422,
#  4194424,
#  2097273,
#  1048703,
#  127,
#  3145858,
#  1048707,
#  3145859,
#  135,
#  4194449,
#  1048724,
#  3145877,
#  1048726,
#  1048727,
#  3145883,
#  3145884,
#  3145885,
#  4194460,
#  159,
#  1048737,
#  4194468,
#  4194469,
#  4194470,
#  2097319,
#  4194471,
#  5243047,
#  5243051,
#  5243052,
#  5243053,
#  3145903,
#  3145904,
#  4194481,
#  4194484,
#  3145912,
#  2097337,
#  3145916,
#  3145917,
#  191,
#  197,
#  199,
#  4194503,
#  2097353,
#  1048778,
#  4194511,
#  5243093,
#  5243097,
#  1048796,
#  1048799,
#  4194532,
#  3145963,
#  2097388,
#  3145965,
#  3145966,
#  3145967,
#  5243117,
#  2097399,
#  2097403,
#  4194556,
#  1048832,
#  3145985,
#  5243136,
#  3145987,
#  3145988,
#  5243139,
#  4194570,
#  2097420,
#  1048854,
#  5243158,
#  1048856,
#  5243161,
#  2097434,
#  2097435,
#  3146012,
#  3146013,
#  4194586,
#  3146017,
#  2097443,
#  3146020,
#  2097445,
#  4194601,
#  5243177,
#  2097452,
#  1048877,
#  302,
#  4194606,
#  304,
#  1048880,
#  1048881,
#  1048882,
#  2097456,
#  2097457,
#  3146033,
#  4194607,
#  3146040,
#  4194614,
#  314,
#  315,
#  5243188,
#  2097469,
#  4194622,
#  5243192,
#  320,
#  5243193,
#  2097474,
#  5243199,
#  4194628,
#  2097477,
#  5243203,
#  5243209,
#  1048909,
#  335,
#  337,
#  1048913,
#  2097490,
#  4194642,
#  1048917,
#  3146070,
#  3146071,
#  4194644,
#  345,
#  346,
#  2097499,
#  1048927,
#  1048929,
#  2097508,
#  5243239,
#  1048943,
#  3146096,
#  4194673,
#  5243247,
#  4194675,
#  5243250,
#  3146112,
#  5243267,
#  1048965,
#  1048966,
#  4194695,
#  1048970,
#  4194698,
#  1048974,
#  2097551,
#  1048978,
#  407,
#  408,
#  409,
#  410,
#  2097560,
#  5243294,
#  5243295,
#  1048992,
#  2097569,
#  3146145,
#  5243296,
#  1048996,
#  2097572,
#  3146149,
#  3146150,
#  4194726,
#  4194727,
#  3146159,
#  3146160,
#  5243312,
#  5243314,
#  2097587,
#  5243315,
#  437,
#  1049016,
#  5243326,
#  1049025,
#  3146179,
#  3146181,
#  4194758,
#  456,
#  2097609,
#  3146186,
#  4194762,
#  464,
#  465,
#  3146192,
#  4194771,
#  5243345,
#  5243349,
#  5243353,
#  4194781,
#  1049056,
#  4194787,
#  484,
#  5243363,
#  4194790,
#  3146215,
#  3146217,
#  5243369,
#  3146223,
#  3146224,
#  2097649,
#  1049074,
#  3146225,
#  4194802,
#  4194808,
#  5243385,
#  507,
#  3146236,
#  513,
#  1049089,
#  5243394,
#  1049094,
#  5243399,
#  2097672,
#  3146249,
#  2097680,
#  1049106,
#  4194834,
#  2097685,
#  534,
#  5243414,
#  3146266,
#  2097691,
#  541,
#  1049121,
#  2097697,
#  1049122,
#  4194852,
#  5243432,
#  3146283,
#  4194860,
#  4194859,
#  4194862,
#  1049136,
#  3146290,
#  3146291,
#  566,
#  567,
#  4194873,
#  5243451,
#  2097723,
#  5243457,
#  3146309,
#  5243461,
#  3146311,
#  3146313,
#  587,
#  3146315,
#  3146316,
#  4194893,
#  4194895,
#  593,
#  5243473,
#  595,
#  596,
#  597,
#  1049172,
#  2097748,
#  4194899,
#  5243481,
#  5243476,
#  5243477,
#  4194908,
#  2097760,
#  2097761,
#  1049186,
#  4194917,
#  614,
#  1049190,
#  3146343,
#  5243497,
#  4194925,
#  1049198,
#  1049201,
#  4194930,
#  2097781,
#  4194934,
#  4194935,
#  5243510,
#  1049209,
#  5243512,
#  3146363,
#  3146364,
#  1049215,
#  5243523,
#  5243525,
#  646,
#  647,
#  648,
#  1049222,
#  1049228,
#  1049229,
#  1049233,
#  5243537,
#  1049239,
#  1049243,
#  5243556,
#  4194981,
#  680,
#  3146412,
#  2097839,
#  2097841,
#  5243569,
#  5243570,
#  694,
#  2097846,
#  4195002,
#  702,
#  3146432,
#  4195009,
#  2097861,
#  5243591,
#  4195017,
#  5243594,
#  1049291,
#  3146445,
#  2097870,
#  3146446,
#  4195021,
#  5243597,
#  5243599,
#  4195028,
#  5243608,
#  4195036,
#  734,
#  736,
#  5243617,
#  3146467,
#  1049316,
#  5243619,
#  743,
#  744,
#  4195050,
#  1049328,
#  4195057,
#  1049331,
#  4195061,
#  2097911,
#  4195063,
#  762,
#  763,
#  1049339,
#  2097914,
#  3146491,
#  3146492,
#  1049344,
#  4195067,
#  4195072,
#  5243651,
#  3146507,
#  5243659,
#  4195086,
#  5243665,
#  1049362,
#  4195093,
#  1049366,
#  2097943,
#  3146519,
#  4195095,
#  3146522,
#  5243669,
#  5243671,
#  1049373,
#  5243677,
#  801,
#  5243683,
#  5243686,
#  4195111,
#  1049384,
#  5243690,
#  2097964,
#  2097970,
#  5243698,
#  5243701,
#  2097977,
#  826,
#  5243705,
#  4195133,
#  4195134,
#  835,
#  1049413,
#  2097989,
#  4195141,
#  1049416,
#  2097992,
#  2097994,
#  3146570,
#  5243719,
#  5243721,
#  5243728,
#  5243729,
#  5243734,
#  5243735,
#  1049433,
#  5243741,
#  5243742,
#  864,
#  2098018,
#  5243748,
#  1049445,
#  5243750,
#  2098023,
#  4195177,
#  875,
#  4195179,
#  1049455,
#  2098032,
#  1049457,
#  882,
#  4195185,
#  5243761,
#  886,
#  2098038,
#  3146615,
#  5243767,
#  4195194,
#  1049467,
#  2098044,
#  893,
#  3146621,
#  896,
#  4195204,
#  4195205,
#  3146631,
#  4195208,
#  4195210,
#  1049484,
#  2098066,
#  915,
#  2098068,
#  3146642,
#  4195220,
#  2098071,
#  4195222,
#  4195223,
#  2098075,
#  924,
#  925,
#  926,
#  927,
#  3146652,
#  3146654,
#  4195236,
#  5243814,
#  3146663,
#  4195240,
#  5243818,
#  1049519,
#  2098096,
#  2098097,
#  3146673,
#  1049524,
#  5243832,
#  2098106,
#  3146682,
#  956,
#  3146683,
#  3146684,
#  3146685,
#  960,
#  3146686,
#  4195264,
#  4195265,
#  967,
#  2098122,
#  3146698,
#  5243852,
#  1049552,
#  2098132,
#  3146709,
#  5243861,
#  4195287,
#  5243864,
#  2098138,
#  2098139,
#  4195291,
#  5243868,
#  4195295,
#  2098147,
#  4195300,
#  5243876,
#  3146726,
#  3146730,
#  1003,
#  1004,
#  4195308,
#  3146734,
#  1049583,
#  5243882,
#  4195313,
#  1049586,
#  1049587,
#  5243884,
#  1013,
#  2098166,
#  3146742,
#  3146744,
#  5243895,
#  3146746,
#  3146747,
#  3146749,
#  1049598,
#  2098175,
#  1024,
#  1049600,
#  4195327,
#  2098182,
#  3146758,
#  4195334,
#  4195336,
#  3146763,
#  1037,
#  1049614,
#  3146765,
#  3146767,
#  5243919,
#  4195347,
#  4195348,
#  1048,
#  1049,
#  1050,
#  2098203,
#  3146777,
#  3146778,
#  1049630,
#  4195355,
#  5243939,
#  4195365,
#  4195369,
#  4195371,
#  1049644,
#  5243949,
#  2098223,
#  4195376,
#  3146803,
#  3146804,
#  1049653,
#  2098229,
#  5243958,
#  5243962,
#  2098235,
#  1084,
#  5243965,
#  1049663,
#  5243969,
#  2098242,
#  3146818,
#  1049671,
#  3146823,
#  1097,
#  1049674,
#  2098249,
#  2098251,
#  3146825,
#  4195403,
#  1103,
#  1104,
#  5243976,
#  5243982,
#  2098260,
#  4195414,
#  1112,
#  1113,
#  1114,
#  1115,
#  1049690,
#  1049693,
#  2098267,
#  2098271,
#  2098272,
#  4195423,
#  5243995,
#  4195429,
#  3146854,
#  4195430,
#  5244008,
#  1049705,
#  5244009,
#  3146860,
#  1133,
#  2098286,
#  1136,
#  5244016,
#  1138,
#  3146870,
#  4195451,
#  1049725,
#  3146881,
#  3146882,
#  2098309,
#  1159,
#  5244040,
#  1049737,
#  5244044,
#  1049741,
#  1049745,
#  3146897,
#  3146898,
#  2098324,
#  3146899,
#  2098328,
#  1177,
#  1178,
#  4195480,
#  2098332,
#  4195489,
#  1186,
#  1187,
#  1049765,
#  5244070,
#  2098343,
#  1049768,
#  3146920,
#  5244078,
#  4195503,
#  1049776,
#  2098352,
#  1049782,
#  1207,
#  1208,
#  1209,
#  3146935,
#  5244086,
#  4195516,
#  4195517,
#  4195518,
#  1049791,
#  5244092,
#  1049793,
#  3146946,
#  5244099,
#  1221,
#  5244109,
#  5244111,
#  1233,
#  1049809,
#  1235,
#  1049811,
#  3146963,
#  4195539,
#  4195541,
#  1240,
#  1049817,
#  2098392,
#  1049819,
#  2098394,
#  5244122,
#  4195553,
#  5244130,
#  5244131,
#  2098404,
#  5244134,
#  2098407,
#  1049834,
#  4195562,
#  1049838,
#  1049839,
#  4195567,
#  5244144,
#  1270,
#  3146998,
#  4195581,
#  1049854,
#  3147007,
#  3147008,
#  4195584,
#  4195590,
#  1290,
#  3147018,
#  2098444,
#  3147019,
#  5244170,
#  2098450,
#  2098451,
#  5244178,
#  1049879,
#  2098456,
#  1305,
#  1306,
#  1307,
#  1049884,
#  1049885,
#  3147033,
#  1311,
#  1312,
#  2098465,
#  4195610,
#  4195612,
#  4195613,
#  1317,
#  2098469,
#  3147047,
#  4195621,
#  2098473,
#  5244201,
#  2098475,
#  3147052,
#  4195627,
#  4195629,
#  4195630,
#  4195631,
#  3147060,
#  2098485,
#  5244213,
#  3147063,
#  4195641,
#  5244217,
#  1339,
#  3147067,
#  1341,
#  1343,
#  5244225,
#  5244226,
#  3147075,
#  1351,
#  1352,
#  1049927,
#  4195655,
#  1049932,
#  5244236,
#  5244242,
#  2098515,
#  3147092,
#  5244243,
#  1049942,
#  1049945,
#  1370,
#  5244250,
#  1049948,
#  5244251,
#  1375,
#  1049951,
#  3147105,
#  5244256,
#  4195688,
#  5244264,
#  1390,
#  1049966,
#  1392,
#  3147119,
#  5244276,
#  5244277,
#  4195703,
#  1400,
#  2098553,
#  5244280,
#  5244282,
#  2098557,
#  3147134,
#  4195709,
#  1408,
#  2098560,
#  4195710,
#  1049987,
#  4195715,
#  4195717,
#  5244290,
#  5244291,
#  4195720,
#  5244293,
#  2098570,
#  2098571,
#  5244298,
#  4195727,
#  2098577,
#  1050005,
#  4195733,
#  1050007,
#  2098583,
#  3147160,
#  5244314,
#  1436,
#  2098589,
#  3147164,
#  2098593,
#  1442,
#  4195747,
#  1050020,
#  1050021,
#  1446,
#  2098604,
#  4195756,
#  2098606,
#  2098607,
#  4195758,
#  1050033,
#  3147185,
#  2098612,
#  4195764,
#  2098614,
#  3147191,
#  1050040,
#  3147192,
#  3147197,
#  2098622,
#  1050047,
#  3147198,
#  3147199,
#  2098626,
#  3147203,
#  4195780,
#  5244350,
#  5244356,
#  5244358,
#  1481,
#  3147209,
#  2098636,
#  1487,
#  2098640,
#  3147220,
#  1050069,
#  5244374,
#  2098651,
#  4195804,
#  5244379,
#  2098654,
#  4195807,
#  5244390,
#  3147240,
#  2098666,
#  4195818,
#  5244397,
#  1050094,
#  4195823,
#  2098672,
#  2098673,
#  1050098,
#  4195824,
#  4195834,
#  4195838,
#  5244417,
#  4195842,
#  2098691,
#  1540,
#  3147267,
#  5244420,
#  4195849,
#  2098699,
#  1050124,
#  3147275,
#  4195855,
#  2098711,
#  4195864,
#  1050137,
#  2098714,
#  5244439,
#  5244452,
#  1050150,
#  5244459,
#  1050158,
#  2098735,
#  3147310,
#  1585,
#  1586,
#  1050163,
#  2098738,
#  4195888,
#  3147318,
#  1050167,
#  5244463,
#  1050169,
#  5244470,
#  4195902,
#  2098751,
#  3147328,
#  5244480,
#  5244481,
#  5244482,
#  2098757,
#  1607,
#  1050183,
#  1611,
#  3147340,
#  3147341,
#  1614,
#  2098767,
#  4195918,
#  1050193,
#  3147346,
#  2098771,
#  3147348,
#  1621,
#  5244497,
#  1623,
#  1624,
#  1050199,
#  4195930,
#  3147355,
#  3147356,
#  3147357,
#  4195936,
#  1050209,
#  2098788,
#  1640,
#  1050216,
#  5244520,
#  2098795,
#  1644,
#  1645,
#  2098796,
#  3147372,
#  5244521,
#  1050225,
#  5244522,
#  5244524,
#  5244525,
#  4195957,
#  5244526,
#  1050235,
#  3147388,
#  3147391,
#  2098816,
#  4195969,
#  2098828,
#  3147407,
#  1050259,
#  2098836,
#  4195988,
#  4195989,
#  2098839,
#  5244563,
#  4195993,
#  1050269,
#  1050270,
#  4195999,
#  4196000,
#  2098850,
#  1050275,
#  3147426,
#  ...]

# %%
database['Primary histology'] == 'carcinoma'
database['Primary histology'] == 'carcinoma'
# Out:
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
# 6           True
# 7          False
# 8          False
# 9           True
# 10          True
# 11          True
# 12         False
# 13          True
# 14          True
# 15          True
# 16          True
# 17          True
# 18          True
# 19          True
# 20          True
# 21          True
# 22          True
# 23          True
# 24          True
# 25          True
# 26          True
# 27          True
# 28          True
# 29          True
#            ...
# 5925510    False
# 5925511     True
# 5925512     True
# 5925513     True
# 5925514     True
# 5925515    False
# 5925516     True
# 5925517     True
# 5925518    False
# 5925519     True
# 5925520     True
# 5925521    False
# 5925522     True
# 5925523     True
# 5925524    False
# 5925525     True
# 5925526    False
# 5925527     True
# 5925528     True
# 5925529     True
# 5925530     True
# 5925531     True
# 5925532     True
# 5925533     True
# 5925534     True
# 5925535     True
# 5925536     True
# 5925537     True
# 5925538     True
# 5925539     True
# Name: Primary histology, Length: 5925540, dtype: bool

# %%
database_laud = database.iloc[shared]

# %%
database_laud['Primary histology']
database_laud['Primary site']
# Out:
# 1048577    lung
# 1048580    lung
# 6          lung
# 2097159    lung
# 3145737    lung
# 3145738    lung
# 3145739    lung
# 2097166    lung
# 3145744    lung
# 18         lung
# 20         lung
# 21         lung
# 22         lung
# 23         lung
# 24         lung
# 25         lung
# 26         lung
# 27         lung
# 1048598    lung
# 1048601    lung
# 1048606    lung
# 1048607    lung
# 32         lung
# 1048608    lung
# 34         lung
# 35         lung
# 2097184    lung
# 37         lung
# 38         lung
# 3145764    lung
#            ...
# 5242807    lung
# 1048506    lung
# 4194235    lung
# 5242813    lung
# 1048512    lung
# 3145664    lung
# 4194241    lung
# 1048517    lung
# 1048518    lung
# 2097094    lung
# 2097095    lung
# 4194249    lung
# 5242821    lung
# 2097099    lung
# 1048529    lung
# 4194258    lung
# 5242834    lung
# 4194262    lung
# 5242845    lung
# 2097118    lung
# 1048548    lung
# 2097125    lung
# 4194277    lung
# 3145704    lung
# 3145705    lung
# 3145706    lung
# 4194288    lung
# 4194293    lung
# 4194294    lung
# 2097149    lung
# Name: Primary site, Length: 611646, dtype: object

# %%
def getGenomePos(sample):
    chr = sample[0]
    chr = chr.replace("chr", "")
    pos = sample[1]
    genomePos = chr + ':' + str(pos) + '-' + str(pos)

    return(genomePos)

# %%
# test
import VCF
df = VCF.dataframe("/Users/lincoln.harris/Desktop/vcf/all/A10_1001000408.vcf")

out = df.apply(getGenomePos, axis=1)
out
out[10]
# Out:
# '1:633714-633714'
