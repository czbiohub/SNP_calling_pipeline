# %%
# script: create_runbatch_config
# authors: Olga Botvinnik & Lincoln Harris
# date: 10.3.18
#
# Trying to build the input file to give gatk_pipeline.rf (required for batch mode run)

# %%
# try to get all of the run prefixes w/in nonImmune_bams_9.27
bucketPrefixes = 's3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/'
f = 'nonImmune_bams_9.27_prefixes.txt'
! aws s3 ls $bucketPrefixes > $f
! cat $f
# Out:
#                            PRE 180226/
#                            PRE 180307/
#                            PRE 180319/
#                            PRE 180320/
#                            PRE 180405/
#                            PRE 180423/
#                            PRE 180516/
#                            PRE 180519/
#                            PRE 180601/
#                            PRE 180604/
#                            PRE 180831/
#                            PRE 180911/
# 2018-09-28 17:24:17          0

# %%
# read run names into a dataframe
#     with pandas!!
import pandas as pd
pd.options.display.max_colwidth = 500 # module config? 

runs_df = pd.read_table(f, delim_whitespace=True, header=None, names=['is_prefix', 'run_name'])
runs_df
# Out:
#      is_prefix  run_name
# 0          PRE   180226/
# 1          PRE   180307/
# 2          PRE   180319/
# 3          PRE   180320/
# 4          PRE   180405/
# 5          PRE   180423/
# 6          PRE   180516/
# 7          PRE   180519/
# 8          PRE   180601/
# 9          PRE   180604/
# 10         PRE   180831/
# 11         PRE   180911/
# 12  2018-09-28  17:24:17

# %%
# can i add a full_path col? 
runs_df['full_path'] = 's3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/' + runs_df['run_name']
runs_df
# Out:
#      is_prefix  run_name  \
# 0          PRE   180226/
# 1          PRE   180307/
# 2          PRE   180319/
# 3          PRE   180320/
# 4          PRE   180405/
# 5          PRE   180423/
# 6          PRE   180516/
# 7          PRE   180519/
# 8          PRE   180601/
# 9          PRE   180604/
# 10         PRE   180831/
# 11         PRE   180911/
# 12  2018-09-28  17:24:17
#
#                                                                 full_path
# 0    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/
# 1    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/
# 2    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180319/
# 3    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180320/
# 4    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180405/
# 5    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180423/
# 6    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180516/
# 7    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180519/
# 8    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180601/
# 9    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180604/
# 10   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180831/
# 11   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/
# 12  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/17:24:17

# %%
# get all of the cells in a given run directory
prefix = 's3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/'
txt = 'runX_cells.txt'
! aws s3 ls $prefix > $txt
! cat $txt
# Out:
#                            PRE C3_1001000403/
#                            PRE E3_1001000362/
#                            PRE F1_1001000362/
#                            PRE G5_1001000362/
#                            PRE H1_1001000362/
#                            PRE H7_1001000377/
#                            PRE J11_1001000367/
#                            PRE L2_1001000362/
#                            PRE M10_1001000365/
#                            PRE M2_1001000413/
#                            PRE M3_1001000362/
#                            PRE N2_1001000380/
#                            PRE O23_1001000377/
#                            PRE O24_1001000377/
#                            PRE O7_B001797/

# %%
# read 180226 cell names into a dataframe
cells_df = pd.read_table(txt, delim_whitespace=True, header=None, names=['is_prefix', 'cell_name'])
cells_df
# Out:
#    is_prefix        cell_name
# 0        PRE   C3_1001000403/
# 1        PRE   E3_1001000362/
# 2        PRE   F1_1001000362/
# 3        PRE   G5_1001000362/
# 4        PRE   H1_1001000362/
# 5        PRE   H7_1001000377/
# 6        PRE  J11_1001000367/
# 7        PRE   L2_1001000362/
# 8        PRE  M10_1001000365/
# 9        PRE   M2_1001000413/
# 10       PRE   M3_1001000362/
# 11       PRE   N2_1001000380/
# 12       PRE  O23_1001000377/
# 13       PRE  O24_1001000377/
# 14       PRE      O7_B001797/

# %%
# ls one of our s3 cell directories
test_files = ! aws s3 ls $prefix\C3_1001000403/ # what does backslash do? 
test_files
# Out:
# ['2018-10-05 10:58:28   10894185 C3_1001000403.vcf',
#  '2018-09-28 17:55:52 1693079358 C3_1001000403_S123.homo.Aligned.out.sorted.bam',
#  '2018-09-28 17:57:43    2447520 C3_1001000403_S123.homo.Aligned.out.sorted.bam.bai']

# %%
# get full s3 paths for bam files, then add them to a new col in cells_df

def get_bam(cell):
    s3_location = f'{prefix}{cell}' #f? 
    lines = ! aws s3 ls $s3_location
    bam_line = [x for x in lines if x.endswith('bam')][0] # get the bam file, specifically
    bam_basename = bam_line.split()[-1]
    return f'{s3_location}{bam_basename}'


cells_df['input_bam'] = cells_df['cell_name'].map(get_bam) # applying function, and assigning output to new col in cells_df
cells_df.head()
# Out:
#   is_prefix       cell_name  \
# 0       PRE  C3_1001000403/
# 1       PRE  E3_1001000362/
# 2       PRE  F1_1001000362/
# 3       PRE  G5_1001000362/
# 4       PRE  H1_1001000362/
#
#                                                                                                                           input_bam
# 0  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403_S123.homo.Aligned.out.sorted.bam
# 1   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362_S99.homo.Aligned.out.sorted.bam
# 2  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362_S121.homo.Aligned.out.sorted.bam
# 3  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362_S149.homo.Aligned.out.sorted.bam
# 4  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362_S169.homo.Aligned.out.sorted.bam

# %%
# sanity check
cells_df['input_bam']
# Out:
# 0       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403_S123.homo.Aligned.out.sorted.bam
# 1        s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362_S99.homo.Aligned.out.sorted.bam
# 2       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362_S121.homo.Aligned.out.sorted.bam
# 3       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362_S149.homo.Aligned.out.sorted.bam
# 4       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362_S169.homo.Aligned.out.sorted.bam
# 5       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H7_1001000377/H7_1001000377_S295.homo.Aligned.out.sorted.bam
# 6     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/J11_1001000367/J11_1001000367_S179.homo.Aligned.out.sorted.bam
# 7       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/L2_1001000362/L2_1001000362_S266.homo.Aligned.out.sorted.bam
# 8     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M10_1001000365/M10_1001000365_S166.homo.Aligned.out.sorted.bam
# 9       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M2_1001000413/M2_1001000413_S230.homo.Aligned.out.sorted.bam
# 10      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M3_1001000362/M3_1001000362_S291.homo.Aligned.out.sorted.bam
# 11      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/N2_1001000380/N2_1001000380_S218.homo.Aligned.out.sorted.bam
# 12    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O23_1001000377/O23_1001000377_S179.homo.Aligned.out.sorted.bam
# 13    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O24_1001000377/O24_1001000377_S180.homo.Aligned.out.sorted.bam
# 14             s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O7_B001797/O7_B001797_S67.homo.Aligned.out.sorted.bam
# Name: input_bam, dtype: object

# %%
# add a sample_id col
cells_df['sample_id'] = cells_df.cell_name.str.strip('/') # getting rid of the forward slashes
cells_df.head()
# Out:
#   is_prefix       cell_name  \
# 0       PRE  C3_1001000403/
# 1       PRE  E3_1001000362/
# 2       PRE  F1_1001000362/
# 3       PRE  G5_1001000362/
# 4       PRE  H1_1001000362/
#
#                                                                                                                           input_bam  \
# 0  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403_S123.homo.Aligned.out.sorted.bam
# 1   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362_S99.homo.Aligned.out.sorted.bam
# 2  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362_S121.homo.Aligned.out.sorted.bam
# 3  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362_S149.homo.Aligned.out.sorted.bam
# 4  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362_S169.homo.Aligned.out.sorted.bam
#
#        sample_id             id
# 0  C3_1001000403  C3_1001000403
# 1  E3_1001000362  E3_1001000362
# 2  F1_1001000362  F1_1001000362
# 3  G5_1001000362  G5_1001000362
# 4  H1_1001000362  H1_1001000362

# %%
# building the output vcf string
import os

cells_df['output_prefix'] = cells_df['input_bam'].map(os.path.dirname)
cells_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-81fc8d4401c0> in <module>()
#       4 cells_df['output_prefix'] = cells_df['input_bam'].map(os.path.dirname)
#       5 cells_df.head()
# ----> 6 cells_df.type()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
# building the output vcf string
cells_df['output_vcf'] = cells_df.apply( # not sure how this works
    lambda x: '{output_prefix}/{sample_id}.vcf'.format(**x), axis=1)
cells_df.head()
# Out:
#   is_prefix       cell_name  \
# 0       PRE  C3_1001000403/
# 1       PRE  E3_1001000362/
# 2       PRE  F1_1001000362/
# 3       PRE  G5_1001000362/
# 4       PRE  H1_1001000362/
#
#                                                                                                                           input_bam  \
# 0  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403_S123.homo.Aligned.out.sorted.bam
# 1   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362_S99.homo.Aligned.out.sorted.bam
# 2  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362_S121.homo.Aligned.out.sorted.bam
# 3  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362_S149.homo.Aligned.out.sorted.bam
# 4  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362_S169.homo.Aligned.out.sorted.bam
#
#        sample_id             id  \
# 0  C3_1001000403  C3_1001000403
# 1  E3_1001000362  E3_1001000362
# 2  F1_1001000362  F1_1001000362
# 3  G5_1001000362  G5_1001000362
# 4  H1_1001000362  H1_1001000362
#
#                                                                        output_prefix  \
# 0  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403
# 1  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362
# 2  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362
# 3  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362
# 4  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362
#
#                                                                                             output_vcf
# 0  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403.vcf
# 1  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362.vcf
# 2  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362.vcf
# 3  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362.vcf
# 4  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362.vcf

# %%
# subset cells_df by only what we want
cols_to_keep = ['input_bam', 'sample_id', 'output_vcf']

samples_df = cells_df[cols_to_keep]
samples_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-29974e103a69> in <module>()
#       2 cols_to_keep = ['input_bam', 'sample_id', 'output_vcf']
#       3
# ----> 4 samples_df = cells_df[cols_to_keep]
#       5 samples_df
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['sample_id' 'output_vcf'] not in index"

# %%
# writeFunc()
#     write this guy to a file
def writeFunc():
    import json

    out_dir = '../gatk/180226_test'

    # write samples_df to file
    ! mkdir -p $out_dir
    samples_df.to_csv(f'{out_dir}/samples.csv', index=False)

    # write a config file
    config =     {
        "program": "../../reflow/gatk_pipeline.rf",
        "runs_file": "samples.csv"
    }

    with open(f'{out_dir}/config.json', 'w') as f:
        json.dump(config, f)
    
    ! head -n 3 $out_dir/samples.csv $out_dir/config.json
# Out:
# ==> ../gatk/180226_test/samples.csv <==
# id,input_bam,sample_id,output_vcf
# C3_1001000403,s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403_S123.homo.Aligned.out.sorted.bam,C3_1001000403,s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403.vcf
# E3_1001000362,s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362_S99.homo.Aligned.out.sorted.bam,E3_1001000362,s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362.vcf
#
# ==> ../gatk/180226_test/config.json <==
# {"program": "../../reflow/gatk_pipeline.rf", "runs_file": "samples.csv"}

# %%
# can we make a function or a class to do everything we just did? 

# get_bam()
#     gets full paths to bam files
def get_bam(cell):
    s3_location = f'{prefix}{cell}' #f? 
    lines = ! aws s3 ls $s3_location
    bam_line = [x for x in lines if x.endswith('bam')][0] # get the bam file, specifically
    bam_basename = bam_line.split()[-1]
    return f'{s3_location}{bam_basename}'

# driver()
#     Gets cell names given a prefix, and sets up dataframe
def driver(prefix):
    #print("in driver")
    txt = 'runX_cells.txt'
    ! aws s3 ls $prefix > $txt
    
    # read into a pandas dataframe
    cells_df = pd.read_table(txt, delim_whitespace=True, header=None, names=['is_prefix', 'cell_name'])

    # call get_bam() and add 'input_bam' col
    cells_df['input_bam'] = cells_df['cell_name'].map(get_bam) 
    
    # get rid of forward slashes and add 'sample_id' col
    cells_df['sample_id'] = cells_df.cell_name.str.strip('/')
    
    # add output_prefix col
    cells_df['output_prefix'] = cells_df['input_bam'].map(os.path.dirname)
    
    # building the output vcf string
    cells_df['output_vcf'] = cells_df.apply( # not sure how this works
    lambda x: '{output_prefix}/{sample_id}.vcf'.format(**x), axis=1)
    
    # subset cells_df by only what we want
    cols_to_keep = ['input_bam', 'sample_id', 'output_vcf']
    samples_df = cells_df[cols_to_keep]
    
    return(samples_df)

# %%
# call this our Main() i guess
#       run driver function

big_df = pd.DataFrame() # init empty dataframe

for i in range(0, len(runs_df.index)-1):
    global prefix
    prefix = runs_df['full_path'][i]
    print(prefix)
    curr_df = driver(prefix)
    toConcat = [big_df, curr_df]
    big_df = pd.concat(toConcat)
    
big_df.head()
# Out:
# s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/
# s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/
# s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180319/
# ^C
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-ca75cd42efaf> in <module>()
#       6     prefix = runs_df['full_path'][i]
#       7     print(prefix)
# ----> 8     curr_df = driver(prefix)
#       9     toConcat = [big_df, curr_df]
#      10     big_df = pd.concat(toConcat)
#
# <ipython-input-16-24199da341db> in driver(prefix)
#      21
#      22     # call get_bam() and add 'input_bam' col
# ---> 23     cells_df['input_bam'] = cells_df['cell_name'].map(get_bam)
#      24
#      25     # get rid of forward slashes and add 'sample_id' col
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2156         else:
#    2157             # arg is a function
# -> 2158             new_values = map_f(values, arg)
#    2159
#    2160         return self._constructor(new_values,
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-16-24199da341db> in get_bam(cell)
#       6     s3_location = f'{prefix}{cell}' #f?
#       7     lines = get_ipython().getoutput('aws s3 ls $s3_location')
# ----> 8     bam_line = [x for x in lines if x.endswith('bam')][0] # get the bam file, specifically
#       9     bam_basename = bam_line.split()[-1]
#      10     return f'{s3_location}{bam_basename}'
#
# IndexError: list index out of range

# %%
big_df
# Out:
#                                                                                                                               input_bam  \
# 0      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403_S123.homo.Aligned.out.sorted.bam
# 1       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362_S99.homo.Aligned.out.sorted.bam
# 2      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362_S121.homo.Aligned.out.sorted.bam
# 3      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362_S149.homo.Aligned.out.sorted.bam
# 4      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362_S169.homo.Aligned.out.sorted.bam
# 5      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H7_1001000377/H7_1001000377_S295.homo.Aligned.out.sorted.bam
# 6    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/J11_1001000367/J11_1001000367_S179.homo.Aligned.out.sorted.bam
# 7      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/L2_1001000362/L2_1001000362_S266.homo.Aligned.out.sorted.bam
# 8    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M10_1001000365/M10_1001000365_S166.homo.Aligned.out.sorted.bam
# 9      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M2_1001000413/M2_1001000413_S230.homo.Aligned.out.sorted.bam
# 10     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M3_1001000362/M3_1001000362_S291.homo.Aligned.out.sorted.bam
# 11     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/N2_1001000380/N2_1001000380_S218.homo.Aligned.out.sorted.bam
# 12   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O23_1001000377/O23_1001000377_S179.homo.Aligned.out.sorted.bam
# 13   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O24_1001000377/O24_1001000377_S180.homo.Aligned.out.sorted.bam
# 14            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O7_B001797/O7_B001797_S67.homo.Aligned.out.sorted.bam
# 0          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A10_B000863/A10_B000863_S250.homo.Aligned.out.sorted.bam
# 1           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A11_B000861/A11_B000861_S83.homo.Aligned.out.sorted.bam
# 2           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A11_B003067/A11_B003067_S95.homo.Aligned.out.sorted.bam
# 3           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A14_B003067/A14_B003067_S98.homo.Aligned.out.sorted.bam
# 4          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A16_B003654/A16_B003654_S112.homo.Aligned.out.sorted.bam
# 5          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A17_B003654/A17_B003654_S113.homo.Aligned.out.sorted.bam
# 6          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A18_B003654/A18_B003654_S114.homo.Aligned.out.sorted.bam
# 7          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A19_B003654/A19_B003654_S115.homo.Aligned.out.sorted.bam
# 8            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B000863/A1_B000863_S241.homo.Aligned.out.sorted.bam
# 9             s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B002568/A1_B002568_S13.homo.Aligned.out.sorted.bam
# 10            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B003067/A1_B003067_S85.homo.Aligned.out.sorted.bam
# 11           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B003646/A1_B003646_S109.homo.Aligned.out.sorted.bam
# 12           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B003648/A1_B003648_S145.homo.Aligned.out.sorted.bam
# 13         s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A21_B003654/A21_B003654_S117.homo.Aligned.out.sorted.bam
# 14         s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A22_B003067/A22_B003067_S106.homo.Aligned.out.sorted.bam
# ..                                                                                                                                  ...
# 507        s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P21_B003646/P21_B003646_S189.homo.Aligned.out.sorted.bam
# 508        s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P22_B003654/P22_B003654_S178.homo.Aligned.out.sorted.bam
# 509        s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P23_B000281/P23_B000281_S275.homo.Aligned.out.sorted.bam
# 510          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P2_B000281/P2_B000281_S254.homo.Aligned.out.sorted.bam
# 511          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P2_B000861/P2_B000861_S134.homo.Aligned.out.sorted.bam
# 512          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P2_B003067/P2_B003067_S146.homo.Aligned.out.sorted.bam
# 513          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P3_B000281/P3_B000281_S255.homo.Aligned.out.sorted.bam
# 514          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P3_B000861/P3_B000861_S135.homo.Aligned.out.sorted.bam
# 515            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P3_B000863/P3_B000863_S3.homo.Aligned.out.sorted.bam
# 516          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P3_B003067/P3_B003067_S147.homo.Aligned.out.sorted.bam
# 517          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P4_B000281/P4_B000281_S256.homo.Aligned.out.sorted.bam
# 518          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P4_B000861/P4_B000861_S136.homo.Aligned.out.sorted.bam
# 519          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P4_B003067/P4_B003067_S148.homo.Aligned.out.sorted.bam
# 520          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P5_B000281/P5_B000281_S257.homo.Aligned.out.sorted.bam
# 521          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P5_B000861/P5_B000861_S137.homo.Aligned.out.sorted.bam
# 522            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P5_B000863/P5_B000863_S5.homo.Aligned.out.sorted.bam
# 523          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P6_B000281/P6_B000281_S258.homo.Aligned.out.sorted.bam
# 524          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P6_B000861/P6_B000861_S138.homo.Aligned.out.sorted.bam
# 525            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P6_B000863/P6_B000863_S6.homo.Aligned.out.sorted.bam
# 526          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P6_B003646/P6_B003646_S174.homo.Aligned.out.sorted.bam
# 527          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P7_B000281/P7_B000281_S259.homo.Aligned.out.sorted.bam
# 528          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P7_B000861/P7_B000861_S139.homo.Aligned.out.sorted.bam
# 529          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P7_B003648/P7_B003648_S211.homo.Aligned.out.sorted.bam
# 530          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P8_B000281/P8_B000281_S260.homo.Aligned.out.sorted.bam
# 531          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P8_B000861/P8_B000861_S140.homo.Aligned.out.sorted.bam
# 532            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P8_B000863/P8_B000863_S8.homo.Aligned.out.sorted.bam
# 533          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P8_B003648/P8_B003648_S212.homo.Aligned.out.sorted.bam
# 534          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P9_B000281/P9_B000281_S261.homo.Aligned.out.sorted.bam
# 535          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P9_B000861/P9_B000861_S141.homo.Aligned.out.sorted.bam
# 536          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P9_B003067/P9_B003067_S153.homo.Aligned.out.sorted.bam
#
#           sample_id  \
# 0     C3_1001000403
# 1     E3_1001000362
# 2     F1_1001000362
# 3     G5_1001000362
# 4     H1_1001000362
# 5     H7_1001000377
# 6    J11_1001000367
# 7     L2_1001000362
# 8    M10_1001000365
# 9     M2_1001000413
# 10    M3_1001000362
# 11    N2_1001000380
# 12   O23_1001000377
# 13   O24_1001000377
# 14       O7_B001797
# 0       A10_B000863
# 1       A11_B000861
# 2       A11_B003067
# 3       A14_B003067
# 4       A16_B003654
# 5       A17_B003654
# 6       A18_B003654
# 7       A19_B003654
# 8        A1_B000863
# 9        A1_B002568
# 10       A1_B003067
# 11       A1_B003646
# 12       A1_B003648
# 13      A21_B003654
# 14      A22_B003067
# ..              ...
# 507     P21_B003646
# 508     P22_B003654
# 509     P23_B000281
# 510      P2_B000281
# 511      P2_B000861
# 512      P2_B003067
# 513      P3_B000281
# 514      P3_B000861
# 515      P3_B000863
# 516      P3_B003067
# 517      P4_B000281
# 518      P4_B000861
# 519      P4_B003067
# 520      P5_B000281
# 521      P5_B000861
# 522      P5_B000863
# 523      P6_B000281
# 524      P6_B000861
# 525      P6_B000863
# 526      P6_B003646
# 527      P7_B000281
# 528      P7_B000861
# 529      P7_B003648
# 530      P8_B000281
# 531      P8_B000861
# 532      P8_B000863
# 533      P8_B003648
# 534      P9_B000281
# 535      P9_B000861
# 536      P9_B003067
#
#                                                                                                 output_vcf
# 0      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403.vcf
# 1      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362.vcf
# 2      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362.vcf
# 3      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362.vcf
# 4      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362.vcf
# 5      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H7_1001000377/H7_1001000377.vcf
# 6    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/J11_1001000367/J11_1001000367.vcf
# 7      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/L2_1001000362/L2_1001000362.vcf
# 8    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M10_1001000365/M10_1001000365.vcf
# 9      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M2_1001000413/M2_1001000413.vcf
# 10     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M3_1001000362/M3_1001000362.vcf
# 11     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/N2_1001000380/N2_1001000380.vcf
# 12   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O23_1001000377/O23_1001000377.vcf
# 13   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O24_1001000377/O24_1001000377.vcf
# 14           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O7_B001797/O7_B001797.vcf
# 0          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A10_B000863/A10_B000863.vcf
# 1          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A11_B000861/A11_B000861.vcf
# 2          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A11_B003067/A11_B003067.vcf
# 3          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A14_B003067/A14_B003067.vcf
# 4          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A16_B003654/A16_B003654.vcf
# 5          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A17_B003654/A17_B003654.vcf
# 6          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A18_B003654/A18_B003654.vcf
# 7          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A19_B003654/A19_B003654.vcf
# 8            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B000863/A1_B000863.vcf
# 9            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B002568/A1_B002568.vcf
# 10           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B003067/A1_B003067.vcf
# 11           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B003646/A1_B003646.vcf
# 12           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B003648/A1_B003648.vcf
# 13         s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A21_B003654/A21_B003654.vcf
# 14         s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A22_B003067/A22_B003067.vcf
# ..                                                                                                     ...
# 507        s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P21_B003646/P21_B003646.vcf
# 508        s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P22_B003654/P22_B003654.vcf
# 509        s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P23_B000281/P23_B000281.vcf
# 510          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P2_B000281/P2_B000281.vcf
# 511          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P2_B000861/P2_B000861.vcf
# 512          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P2_B003067/P2_B003067.vcf
# 513          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P3_B000281/P3_B000281.vcf
# 514          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P3_B000861/P3_B000861.vcf
# 515          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P3_B000863/P3_B000863.vcf
# 516          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P3_B003067/P3_B003067.vcf
# 517          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P4_B000281/P4_B000281.vcf
# 518          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P4_B000861/P4_B000861.vcf
# 519          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P4_B003067/P4_B003067.vcf
# 520          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P5_B000281/P5_B000281.vcf
# 521          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P5_B000861/P5_B000861.vcf
# 522          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P5_B000863/P5_B000863.vcf
# 523          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P6_B000281/P6_B000281.vcf
# 524          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P6_B000861/P6_B000861.vcf
# 525          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P6_B000863/P6_B000863.vcf
# 526          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P6_B003646/P6_B003646.vcf
# 527          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P7_B000281/P7_B000281.vcf
# 528          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P7_B000861/P7_B000861.vcf
# 529          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P7_B003648/P7_B003648.vcf
# 530          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P8_B000281/P8_B000281.vcf
# 531          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P8_B000861/P8_B000861.vcf
# 532          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P8_B000863/P8_B000863.vcf
# 533          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P8_B003648/P8_B003648.vcf
# 534          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P9_B000281/P9_B000281.vcf
# 535          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P9_B000861/P9_B000861.vcf
# 536          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/P9_B003067/P9_B003067.vcf
#
# [552 rows x 3 columns]
