# %%
#/////////////////////////////////////////////////////////////////////
#/////////////////////////////////////////////////////////////////////
# author: Lincoln
# date: 3/7/19
# script: getDuplicatedVCF_entries
# 
# what to do with these bulk vcfs??
#     what to do with all these heavy ass weights??!
#/////////////////////////////////////////////////////////////////////
#/////////////////////////////////////////////////////////////////////

# %%
import pandas as pd
import VCF
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# feel like this is gonna be important
patientMetadata = pd.read_csv('../cDNA_plate_metadata.csv')
patientMetadata
# Out:
#           plate sample_type    patient_id         DOB  gender  \
# 0           NaN   cell_line         Ewing         NaN     NaN
# 1           NaN   cell_line   Fibroblasts         NaN     NaN
# 2    1001000332   cell_line         H1975         NaN     NaN
# 3    1001000330   cell_line          TPH1         NaN     NaN
# 4    1001000302  Lung_tumor         TH158  1959-11-23  Female
# 5    1001000301  Lung_tumor         TH157  2016-11-25    Male
# 6    1001000292  Lung_tumor         TH156  1973-03-17    Male
# 7    1001000293  Lung_tumor         TH156  1973-03-17    Male
# 8    1001000294  Lung_tumor         TH156  1973-03-17    Male
# 9    1001000295  Lung_tumor         TH156  1973-03-17    Male
# 10   1001000296  Lung_tumor         TH166  1974-12-15    Male
# 11   1001000297  Lung_tumor         TH166  1974-12-15    Male
# 12   1001000298  Lung_tumor         TH166  1974-12-15    Male
# 13   1001000299  Lung_tumor         TH166  1974-12-15    Male
# ...

# %%
import os 
wrkDir = '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scVCF/'
scVCF_list = os.listdir(wrkDir)
scVCF_list
# Out:
# ['A11_1001000408.vcf',
#  'A7_B001545.vcf',
#  'A22_B003771.vcf',
#  'A22_1001000407.vcf',
#  'A21_B003528.vcf',
#  'A22_B003995.vcf',
#  'A7_B003187.vcf',
#  'A10_B001007.vcf',
#  'A13_B003529.vcf',
#  'A8_B003125.vcf',
#  'A3_B003067.vcf',
#  'A1_B003132.vcf',
#  'A12_B002077.vcf',
#  'A1_1001000295.vcf',
#  'A5_B001558.vcf',
#  'A22_B001007.vcf',
#  'A16_B000420.vcf',
#  'A16_B003129.vcf',
#  'A11_B003119.vcf',
#  'A21_B003105.vcf',
#  'A18_B003654.vcf',
#  'A14_B003518.vcf',
#  'A13_B003528.vcf',
#  'A19_B002097.vcf',
#  'A1_B003523.vcf',
#  'A17_B002073.vcf',
#  'A14_B003120.vcf',
#  'A18_B003522.vcf',
#  'A4_B002572.vcf',
#  'A9_B001007.vcf',
#  'A16_B003920.vcf',
#  'A19_1001000408.vcf',
#  'A13_B003112.vcf',
#  'A10_B001548.vcf',
#  'A14_B002572.vcf',
#  'A11_B003523.vcf',
#  'A8_B000573.vcf',
#  'A15_B003776.vcf',
#  'A16_1001000408.vcf',
#  'A6_B001474.vcf',
#  'A22_B002097.vcf',
#  'A3_B003528.vcf',
#  'A8_B003132.vcf',
#  'A8_B003126.vcf',
#  'A5_B000862.vcf',
# ...

# %%
for item in scVCF_list:
    currCell = item.strip('.vcf')
    currPlate = currCell.split('_')[1]
    
    rowToKeep = patientMetadata['plate'] == currPlate
    try:
        currPatient = patientMetadata['patient_id'][rowToKeep]
        print(currPatient.item())
    except:
        print('ERROR')
# Out:
# TH185
# TH179
# TH236
# TH185
# TH179
# TH236
# TH226
# ERROR
# TH171
# TH226
# TH205
# TH226
# TH238
# TH156
# TH179_Normal
# ERROR
# TH238
# TH226
# TH231
# TH222
# TH226
# TH171
# TH179
# TH238_Normal
# TH179
# TH238_Normal
# TH231
# TH171
# TH266
# ERROR
# TH236
# TH185
# TH231
# TH179
# TH266
# TH179
# TH155
# TH248
# TH185
# TH248
# TH238_Normal
# TH179
# TH226
# TH226
# TH220
# TH205
# TH179
# TH179
# TH238
# TH226
# TH231
# TH236
# ERROR
# TH185
# TH238
# TH236
# TH236
# TH169
# TH223
# TH171
# TH231
# TH248
# TH266
# TH238_Normal
# TH248
# TH226
# TH171
# TH179
# TH266
# TH226
# TH222
# TH218
# TH171
# TH248
# TH220
# TH218
# TH236
# TH185
# TH179
# TH103
# TH171
# TH231
# ERROR
# TH225
# TH266
# TH238
# TH236
# TH266
# TH226
# TH231
# TH185
# TH222
# TH266
# TH266
# TH238
# ERROR
# TH266
# TH226
# TH231
# TH222
# TH171
# TH220
# TH171
# TH248
# TH179
# TH226
# ERROR
# TH226
# TH179_Normal
# TH231
# TH169
# TH236
# TH185
# TH222
# TH220
# TH226
# TH205
# TH238
# TH226
# ...

# %%
patientsDict = {}

# %%
allPatients = set(patientMetadata['patient_id'])
allPatients
# Out:
# {'Ewing',
#  'Fibroblasts',
#  'H1975',
#  'TH041',
#  'TH067',
#  'TH082',
#  'TH100',
#  'TH103',
#  'TH107',
#  'TH116',
#  'TH124',
#  'TH134_PDX',
#  'TH143B',
#  'TH144',
#  'TH146',
#  'TH150',
#  'TH153',
#  'TH155',
#  'TH156',
#  'TH157',
#  'TH158',
#  'TH166',
#  'TH169',
#  'TH171',
#  'TH172',
#  'TH174',
#  'TH178',
#  'TH179',
#  'TH179_Normal',
#  'TH183',
#  'TH185',
#  'TH187',
#  'TH188',
#  'TH199',
#  'TH205',
#  'TH208',
#  'TH210',
#  'TH214',
#  'TH217',
#  'TH218',
#  'TH220',
#  'TH222',
#  'TH223',
#  'TH225',
#  'TH226',
#  'TH227',
#  'TH231',
#  'TH236',
#  'TH238',
#  'TH238_Normal',
#  'TH248',
#  'TH249',
#  'TH257',
#  'TH266',
#  'TPH1'}

# %%
for item in allPatients:
    patientsDict.update({item:0})

# %%
patientsDict
# Out:
# {'Ewing': 0,
#  'Fibroblasts': 0,
#  'H1975': 0,
#  'TH041': 0,
#  'TH067': 0,
#  'TH082': 0,
#  'TH100': 0,
#  'TH103': 0,
#  'TH107': 0,
#  'TH116': 0,
#  'TH124': 0,
#  'TH134_PDX': 0,
#  'TH143B': 0,
#  'TH144': 0,
#  'TH146': 0,
#  'TH150': 0,
#  'TH153': 0,
#  'TH155': 0,
#  'TH156': 0,
#  'TH157': 0,
#  'TH158': 0,
#  'TH166': 0,
#  'TH169': 0,
#  'TH171': 0,
#  'TH172': 0,
#  'TH174': 0,
#  'TH178': 0,
#  'TH179': 0,
#  'TH179_Normal': 0,
#  'TH183': 0,
#  'TH185': 0,
#  'TH187': 0,
#  'TH188': 0,
#  'TH199': 0,
#  'TH205': 0,
#  'TH208': 0,
#  'TH210': 0,
#  'TH214': 0,
#  'TH217': 0,
#  'TH218': 0,
#  'TH220': 0,
#  'TH222': 0,
#  'TH223': 0,
#  'TH225': 0,
#  'TH226': 0,
#  'TH227': 0,
#  'TH231': 0,
#  'TH236': 0,
#  'TH238': 0,
#  'TH238_Normal': 0,
#  'TH248': 0,
#  'TH249': 0,
#  'TH257': 0,
#  'TH266': 0,
#  'TPH1': 0}

# %%
for item in scVCF_list:
    currCell = item.strip('.vcf')
    currPlate = currCell.split('_')[1]
    
    rowToKeep = patientMetadata['plate'] == currPlate
    
    try:
        currPatient = patientMetadata['patient_id'][rowToKeep]
        currPatientVal = currPatient.item()
        currDictVal = patientsDict[currPatientVal]
        toUpdateVal = currDictVal + 1
        patientsDict.update({currPatientVal:toUpdateVal})
    except:
        print('ERROR')
# Out:
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR
# ERROR

# %%
# what patients do we have a bunch of cells from? 
#     TH226 looks like a good choice
patientsDict
# Out:
# {'Ewing': 0,
#  'Fibroblasts': 0,
#  'H1975': 0,
#  'TH041': 0,
#  'TH067': 8,
#  'TH082': 0,
#  'TH100': 0,
#  'TH103': 6,
#  'TH107': 1,
#  'TH116': 0,
#  'TH124': 0,
#  'TH134_PDX': 0,
#  'TH143B': 0,
#  'TH144': 0,
#  'TH146': 0,
#  'TH150': 0,
#  'TH153': 0,
#  'TH155': 4,
#  'TH156': 1,
#  'TH157': 0,
#  'TH158': 0,
#  'TH166': 0,
#  'TH169': 9,
#  'TH171': 48,
#  'TH172': 0,
#  'TH174': 0,
#  'TH178': 0,
#  'TH179': 49,
#  'TH179_Normal': 19,
#  'TH183': 0,
#  'TH185': 54,
#  'TH187': 0,
#  'TH188': 0,
#  'TH199': 0,
#  'TH205': 22,
#  'TH208': 0,
#  'TH210': 0,
#  'TH214': 0,
#  'TH217': 0,
#  'TH218': 14,
#  'TH220': 20,
#  'TH222': 18,
#  'TH223': 1,
#  'TH225': 2,
#  'TH226': 62,
#  'TH227': 1,
#  'TH231': 31,
#  'TH236': 34,
#  'TH238': 41,
#  'TH238_Normal': 19,
#  'TH248': 43,
#  'TH249': 0,
#  'TH257': 0,
#  'TH266': 35,
#  'TPH1': 0}

# %%
# lets get a list of the cells that come from TH179
TH179_cells = []

for item in scVCF_list:
    currCell = item.strip('.vcf')
    currPlate = currCell.split('_')[1]
    
    rowToKeep = patientMetadata['plate'] == currPlate
    
    try:
        currPatient = patientMetadata['patient_id'][rowToKeep]
        currPatientVal = currPatient.item()
        if currPatientVal == 'TH179':
            TH179_cells.append(currCell)
    except:
        continue

# %%
TH179_cells
# Out:
# ['A7_B001545',
#  'A21_B003528',
#  'A13_B003528',
#  'A1_B003523',
#  'A10_B001548',
#  'A11_B003523',
#  'A3_B003528',
#  'A2_B001557',
#  'A2_B001543',
#  'A8_B003523',
#  'A6_B003528',
#  'A7_B001556',
#  'A5_B001548',
#  'A9_B003577',
#  'A16_B003528',
#  'A15_B003528',
#  'A14_B001557',
#  'A6_B001548',
#  'A7_B003523',
#  'A1_B001551',
#  'A11_B001551',
#  'A11_B001545',
#  'A8_B001545',
#  'A19_B003528',
#  'A1_B001543',
#  'A10_B003528',
#  'A8_B001543',
#  'A8_B001557',
#  'A9_B003528',
#  'A4_B001551',
#  'A1_B001559',
#  'A17_B003528',
#  'A11_B003577',
#  'A7_B003528',
#  'A8_B001548',
#  'A10_B003523',
#  'A12_B003528',
#  'A20_B003528',
#  'A8_B003528',
#  'A9_B001543',
#  'A5_B001545',
#  'A11_B003528',
#  'A1_B003528',
#  'A7_B003577',
#  'A18_B003528',
#  'A9_B001545',
#  'A10_B001545',
#  'A15_B001557',
#  'A14_B003528']

# %%
len(TH179_cells)
# Out:
# 49

# %%
TH179_files = []
fullPath = '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scVCF/'
for item in TH179_cells:
    file = fullPath + item + '.vcf'
    TH179_files.append(file)

# %%
TH179_files
# Out:
# ['/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scVCF/A7_B001545.vcf',
#  '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scVCF/A21_B003528.vcf',
#  '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scVCF/A13_B003528.vcf',
#  '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scVCF/A1_B003523.vcf',
#  '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scVCF/A10_B001548.vcf',
#  '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scVCF/A11_B003523.vcf',
#  '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scVCF/A3_B003528.vcf',
#  '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scVCF/A2_B001557.vcf',
#  '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scVCF/A2_B001543.vcf',
#  '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scVCF/A8_B003523.vcf',
#  '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scVCF/A6_B003528.vcf',
# ...

# %%
# works!
#copyPath = '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/scTH179/'
#for file in TH179_files:
#    ! cp $file $copyPath

# %%
#////////////////////////////////////////////////////////////////////
# 
# ok, now lets compare
#
#////////////////////////////////////////////////////////////////////

# %%
TH179_df = VCF.dataframe('bulkTH179/TH179.vcf')
TH179_df
# Out:
#                    CHROM     POS           ID REF  ALT     QUAL FILTER  \
# 0                   chr1   14542            .   A    G    42.60      .
# 1                   chr1   14574            .   A    G   272.60      .
# 2                   chr1   14599     rs707680   T    A   351.60      .
# 3                   chr1   14604  rs541940975   A    G   486.60      .
# 4                   chr1   14610            .   T    C   519.60      .
# 5                   chr1   14653            .   C    T   936.60      .
# 6                   chr1   14677            .   G    A   548.60      .
# 7                   chr1   14773            .   C    T  1717.60      .
# 8                   chr1   14907            .   A    G   215.60      .
# 9                   chr1   14930    rs6682385   A    G   291.60      .
# 10                  chr1   15045            .   C    T    69.60      .
# 11                  chr1   15118            .   A    G    67.60      .
# ...

# %%
A10_B001545_df = VCF.dataframe('scTH179/A10_B001545.vcf')
A10_B001545_df
# Out:
#                   CHROM     POS          ID                            REF  \
# 0                  chr1  631191           .                              G
# 1                  chr1  631192           .                              A
# 2                  chr1  631197           .                              G
# 3                  chr1  631199           .                              C
# 4                  chr1  631811           .                              C
# 5                  chr1  631861           .                              G
# 6                  chr1  631862           .                              G
# 7                  chr1  631895           .                              T
# 8                  chr1  632199           .                              C
# 9                  chr1  632317   rs1972379                              G
# 10                 chr1  633727           .                              C
# ...

# %%
TH179_df_trimmed = TH179_df[['CHROM', 'POS', 'ID', 'REF', 'ALT']]
TH179_df_trimmed
# Out:
#                    CHROM     POS           ID REF  ALT
# 0                   chr1   14542            .   A    G
# 1                   chr1   14574            .   A    G
# 2                   chr1   14599     rs707680   T    A
# 3                   chr1   14604  rs541940975   A    G
# 4                   chr1   14610            .   T    C
# 5                   chr1   14653            .   C    T
# 6                   chr1   14677            .   G    A
# 7                   chr1   14773            .   C    T
# 8                   chr1   14907            .   A    G
# 9                   chr1   14930    rs6682385   A    G
# 10                  chr1   15045            .   C    T
# 11                  chr1   15118            .   A    G
# 12                  chr1   15274            .   A    T
# 13                  chr1   15820    rs2691315   G    T
# 14                  chr1   15903  rs557514207   G   GC
# 15                  chr1   15906            .   A    G
# ...

# %%
A10_B001545_df_trimmed = A10_B001545_df[['CHROM', 'POS', 'ID', 'REF', 'ALT']]
A10_B001545_df_trimmed
# Out:
#                   CHROM     POS          ID                            REF  \
# 0                  chr1  631191           .                              G
# 1                  chr1  631192           .                              A
# 2                  chr1  631197           .                              G
# 3                  chr1  631199           .                              C
# 4                  chr1  631811           .                              C
# 5                  chr1  631861           .                              G
# 6                  chr1  631862           .                              G
# 7                  chr1  631895           .                              T
# 8                  chr1  632199           .                              C
# 9                  chr1  632317   rs1972379                              G
# 10                 chr1  633727           .                              C
# ...

# %%
concat = pd.concat([TH179_df_trimmed, A10_B001545_df_trimmed])
concat
# Out:
#                   CHROM    POS           ID   REF ALT
# 0                  chr1  14542            .     A   G
# 1                  chr1  14574            .     A   G
# 2                  chr1  14599     rs707680     T   A
# 3                  chr1  14604  rs541940975     A   G
# 4                  chr1  14610            .     T   C
# 5                  chr1  14653            .     C   T
# 6                  chr1  14677            .     G   A
# 7                  chr1  14773            .     C   T
# 8                  chr1  14907            .     A   G
# 9                  chr1  14930    rs6682385     A   G
# 10                 chr1  15045            .     C   T
# 11                 chr1  15118            .     A   G
# 12                 chr1  15274            .     A   T
# 13                 chr1  15820    rs2691315     G   T
# 14                 chr1  15903  rs557514207     G  GC
# 15                 chr1  15906            .     A   G
# ...

# %%
rowsToKeep = concat.duplicated()
shared = concat[rowsToKeep]
shared
# Out:
#                          CHROM        POS          ID REF   ALT
# 27                        chr1     976215   rs7417106   A     G
# 29                        chr1     976653           .   C     T
# 36                        chr1     999842   rs2298214   C     A
# 37                        chr1    1000079   rs3128113   A     G
# 38                        chr1    1000112   rs3121571   G     T
# 51                        chr1    1013541     rs15842   T     C
# 53                        chr1    1014274      rs8997   A     G
# 67                        chr1    1055393   rs2799072   C     T
# 68                        chr1    1055426   rs2799073   G     A
# 71                        chr1    1223251   rs6603781   A     G
# 76                        chr1    1407232   rs2275915   G     C
# 78                        chr1    1616547   rs7418389   T     C
# 95                        chr1    3480891   rs1051515   G     A
# 96                        chr1    3481000   rs1051517   C     T
# ...

# %%
# 2697 entries shared!!
shared.reset_index(drop=True)
# Out:
#                         CHROM        POS          ID REF   ALT
# 0                        chr1     976215   rs7417106   A     G
# 1                        chr1     976653           .   C     T
# 2                        chr1     999842   rs2298214   C     A
# 3                        chr1    1000079   rs3128113   A     G
# 4                        chr1    1000112   rs3121571   G     T
# 5                        chr1    1013541     rs15842   T     C
# 6                        chr1    1014274      rs8997   A     G
# 7                        chr1    1055393   rs2799072   C     T
# 8                        chr1    1055426   rs2799073   G     A
# 9                        chr1    1223251   rs6603781   A     G
# 10                       chr1    1407232   rs2275915   G     C
# 11                       chr1    1616547   rs7418389   T     C
# 12                       chr1    3480891   rs1051515   G     A
# 13                       chr1    3481000   rs1051517   C     T
# ...

# %%
# can we turn this into a func? 
basePATH = '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/'

def getDuplicatedVCF_entries(patient, cell):
    patientPATH = basePATH + 'bulkVCF/' + patient + '.vcf'
    cellPATH = basePATH + 'scVCF/' + cell + '.vcf'
    
    patient_df = VCF.dataframe(patientPATH)
    cell_df = VCF.dataframe(cellPATH)
    
    patient_df_trimmed = patient_df[['CHROM', 'POS', 'ID', 'REF', 'ALT']]
    cell_df_trimmed = cell_df[['CHROM', 'POS', 'ID', 'REF', 'ALT']]
    
    concat = pd.concat([patient_df_trimmed, cell_df_trimmed])
    rowsToKeep = concat.duplicated()
    shared = concat[rowsToKeep]
    shared = shared.reset_index(drop=True)
    
    return(shared)

# %%
# FUCK YEAH this works!!
sharedVCF_df = getDuplicatedVCF_entries('TH179', 'A10_B001545')
sharedVCF_df
# Out:
#                         CHROM        POS          ID REF   ALT
# 0                        chr1     976215   rs7417106   A     G
# 1                        chr1     976653           .   C     T
# 2                        chr1     999842   rs2298214   C     A
# 3                        chr1    1000079   rs3128113   A     G
# 4                        chr1    1000112   rs3121571   G     T
# 5                        chr1    1013541     rs15842   T     C
# 6                        chr1    1014274      rs8997   A     G
# 7                        chr1    1055393   rs2799072   C     T
# 8                        chr1    1055426   rs2799073   G     A
# 9                        chr1    1223251   rs6603781   A     G
# 10                       chr1    1407232   rs2275915   G     C
# 11                       chr1    1616547   rs7418389   T     C
# 12                       chr1    3480891   rs1051515   G     A
# 13                       chr1    3481000   rs1051517   C     T
# ...

# %%
sharedVCF_df = getDuplicatedVCF_entries('TH179', 'A9_B003528')
sharedVCF_df
# Out:
#                  CHROM        POS           ID      REF      ALT
# 0                 chr1     942451            .        T        C
# 1                 chr1     944296    rs6605067        G        A
# 2                 chr1     944307       rs2839        T        C
# 3                 chr1    1013541      rs15842        T        C
# 4                 chr1    1014274       rs8997        A        G
# 5                 chr1    1082764    rs9442395        T        C
# 6                 chr1    1223251    rs6603781        A        G
# 7                 chr1    1312114      rs12103        T        C
# 8                 chr1    1313807   rs12142199        G        A
# 9                 chr1    1319461   rs10907179        C        G
# 10                chr1    1352965      rs13249        A        G
# 11                chr1    1353091    rs3766183        C        T
# 12                chr1    1353203            .        C        G
# ...

# %%
# but actually what i want to do is return the UNIQUE entries to the cell, NOT the dups
basePATH = '/Users/lincoln.harris/code/SNP_calling_pipeline/bulkAnalysis/'

def getUniqueVCF_entries(patient, cell):
    patientPATH = basePATH + 'bulkVCF/' + patient + '.vcf'
    cellPATH = basePATH + 'scVCF/' + cell + '.vcf'
    
    patient_df = VCF.dataframe(patientPATH)
    cell_df = VCF.dataframe(cellPATH)
    
    patient_df_trimmed = patient_df[['CHROM', 'POS', 'ID', 'REF', 'ALT']]
    cell_df_trimmed = cell_df[['CHROM', 'POS', 'ID', 'REF', 'ALT']]
    
    # get whats SHARED between patient and cell 
    #    FIND GERMLINE MUTATIONS
    patient_cell_concat = pd.concat([patient_df_trimmed, cell_df_trimmed])
    rowsToKeep = patient_cell_concat.duplicated()
    patient_cell_shared = patient_cell_concat[rowsToKeep]
    patient_cell_shared = patient_cell_shared.reset_index(drop=True)
    
    # now go back to the original cell df, pull out whats UNIQUE 
    #     THIS IS THE GERMLINE FILTER!!
    cell_cell_concat = pd.concat([cell_df_trimmed, patient_cell_shared])
    cell_cell_concat_noDups = cell_cell_concat.drop_duplicates(keep=False)
    cell_cell_concat_noDups = cell_cell_concat_noDups.reset_index(drop=True)
    
    return(cell_cell_concat_noDups)

# %%
A9_B003528_unique = getDuplicatedVCF_entries('TH179', 'A9_B003528')
A9_B003528_unique
# Out:
#                  CHROM        POS           ID      REF      ALT
# 0                 chr1     942451            .        T        C
# 1                 chr1     944296    rs6605067        G        A
# 2                 chr1     944307       rs2839        T        C
# 3                 chr1    1013541      rs15842        T        C
# 4                 chr1    1014274       rs8997        A        G
# 5                 chr1    1082764    rs9442395        T        C
# 6                 chr1    1223251    rs6603781        A        G
# 7                 chr1    1312114      rs12103        T        C
# 8                 chr1    1313807   rs12142199        G        A
# 9                 chr1    1319461   rs10907179        C        G
# 10                chr1    1352965      rs13249        A        G
# 11                chr1    1353091    rs3766183        C        T
# 12                chr1    1353203            .        C        G
# ...

# %%
# can we do this for every one of a patients cells?

# %%
# maybe best to just write this guy as a csv, then send to getMutationCounts_overall_and_GOI.py
#    i dont think we use the QUAL, FILTER or INFO cols
A9_B003528_unique.to_csv('./filteredOut/A9_B003528_unique.csv', index=False)

# %%
#////////////////////////////////////////////////////////////////////
# 
# now want to get a list of all the patients
#
#////////////////////////////////////////////////////////////////////

# %%
patientMetadata
# Out:
#           plate sample_type    patient_id         DOB  gender  \
# 0           NaN   cell_line         Ewing         NaN     NaN
# 1           NaN   cell_line   Fibroblasts         NaN     NaN
# 2    1001000332   cell_line         H1975         NaN     NaN
# 3    1001000330   cell_line          TPH1         NaN     NaN
# 4    1001000302  Lung_tumor         TH158  1959-11-23  Female
# 5    1001000301  Lung_tumor         TH157  2016-11-25    Male
# 6    1001000292  Lung_tumor         TH156  1973-03-17    Male
# 7    1001000293  Lung_tumor         TH156  1973-03-17    Male
# 8    1001000294  Lung_tumor         TH156  1973-03-17    Male
# 9    1001000295  Lung_tumor         TH156  1973-03-17    Male
# 10   1001000296  Lung_tumor         TH166  1974-12-15    Male
# 11   1001000297  Lung_tumor         TH166  1974-12-15    Male
# 12   1001000298  Lung_tumor         TH166  1974-12-15    Male
# 13   1001000299  Lung_tumor         TH166  1974-12-15    Male
# ...

# %%
patientsList = set(patientMetadata['patient_id'])
patientsList
# Out:
# {'Ewing',
#  'Fibroblasts',
#  'H1975',
#  'TH041',
#  'TH067',
#  'TH082',
#  'TH100',
#  'TH103',
#  'TH107',
#  'TH116',
#  'TH124',
#  'TH134_PDX',
#  'TH143B',
#  'TH144',
#  'TH146',
#  'TH150',
#  'TH153',
#  'TH155',
#  'TH156',
#  'TH157',
#  'TH158',
#  'TH166',
#  'TH169',
#  'TH171',
#  'TH172',
#  'TH174',
#  'TH178',
#  'TH179',
#  'TH179_Normal',
#  'TH183',
#  'TH185',
#  'TH187',
#  'TH188',
#  'TH199',
#  'TH205',
#  'TH208',
#  'TH210',
#  'TH214',
#  'TH217',
#  'TH218',
#  'TH220',
#  'TH222',
#  'TH223',
#  'TH225',
#  'TH226',
#  'TH227',
#  'TH231',
#  'TH236',
#  'TH238',
#  'TH238_Normal',
#  'TH248',
#  'TH249',
#  'TH257',
#  'TH266',
#  'TPH1'}

# %%
#patientsList.remove('Ewing')
patientsList.remove('Fibroblasts')
patientsList.remove('TH134_PDX')
patientsList
# Out:
# {'H1975',
#  'TH041',
#  'TH067',
#  'TH082',
#  'TH100',
#  'TH103',
#  'TH107',
#  'TH116',
#  'TH124',
#  'TH143B',
#  'TH144',
#  'TH146',
#  'TH150',
#  'TH153',
#  'TH155',
#  'TH156',
#  'TH157',
#  'TH158',
#  'TH166',
#  'TH169',
#  'TH171',
#  'TH172',
#  'TH174',
#  'TH178',
#  'TH179',
#  'TH179_Normal',
#  'TH183',
#  'TH185',
#  'TH187',
#  'TH188',
#  'TH199',
#  'TH205',
#  'TH208',
#  'TH210',
#  'TH214',
#  'TH217',
#  'TH218',
#  'TH220',
#  'TH222',
#  'TH223',
#  'TH225',
#  'TH226',
#  'TH227',
#  'TH231',
#  'TH236',
#  'TH238',
#  'TH238_Normal',
#  'TH248',
#  'TH249',
#  'TH257',
#  'TH266',
#  'TPH1'}

# %%
len(patientsList)
# Out:
# 52
