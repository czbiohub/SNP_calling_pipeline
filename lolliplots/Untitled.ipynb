# %%
import pandas as pd

# %%
pd.read_csv('/Users/lincoln.harris/Desktop/fusions_by_patient.csv')
# Out:
#        patientID  ALK--EML4  ALK_any  EML4_any  NTRK_any  RET_any  ROS1_any
# 0          TH185          0        3         5         0        0         0
# 1          TH266          2        1         3         1        2         1
# 2          H1975          0        0         0         0        0         0
# 3          TH171          3        4         2         0        2         0
# 4          TH155          0        0         0         0        0         0
# 5          TH188          0        0         0         0        0         0
# 6          TH082          0        0         0         0        0         0
# 7          TH103          4        3         3         0        0         1
# 8          TH214          0        0         0         0        0         0
# 9          TH153          0        0         0         0        0         0
# 10         TH226          0        2         1         2        1         7
# ...
