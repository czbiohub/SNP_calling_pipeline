# %%
import pandas as pd

# %%
egfr_df = pd.read_csv('/Users/lincoln.harris/code/SNP_calling_pipeline/getMutationCounts/egfr_germline_out_AA.csv', header=None, names=['cell', 'mutations'])
egfr_df
# Out:
#                 cell                                    mutations
# 0        K21_B003995                                           []
# 1     L22_1001000408                                    ['Q787Q']
# 2         A8_B001557                                           []
# 3        L22_B001016                                           []
# 4        C20_B002073                                           []
# 5         D8_B001474                                           []
# 6         C5_B002572                                           []
# 7        E17_B003116                                           []
# 8        A15_B000420                                           []
# 9        H10_B002573                                           []
# 10       I17_B002078                                           []
# 11       D20_B003518                                           []
# 12       M20_B003529                                           []
# ...

# %%
braf_df = pd.read_csv('/Users/lincoln.harris/code/SNP_calling_pipeline/getMutationCounts/braf_germline_out_AA.csv', header=None, names=['cell', 'mutations'])
braf_df
# Out:
#                 cell mutations
# 0        O14_B003125        []
# 1        J15_B003112        []
# 2         D2_B003995        []
# 3        D17_B003930        []
# 4        N19_B003658        []
# 5         L1_B001464        []
# 6         H7_B003577        []
# 7        E17_B001016        []
# 8     N18_1001000339        []
# 9         M7_B003125        []
# 10       L17_B003588        []
# 11       A16_B003120        []
# 12        J3_B001557        []
# 13       O11_B001558        []
# 14       F22_B003528        []
# 15       N16_B002077        []
# 16       P22_B003518        []
# 17        G4_B001464        []
# 18     O9_1001000407        []
# 19       O15_B003518        []
# 20    J15_1001000408        []
# 21        G8_B003187        []
# 22     E4_1001000407        []
# 23       O14_B003771        []
# 24       D20_B001016        []
# 25       P18_B000422        []
# 26    E13_1001000339        []
# 27       H18_B003112        []
# 28        L1_B000863        []
# ...

# %%
egfr_df.shape
# Out:
# (9881, 2)

# %%
braf_df.shape
# Out:
# (9881, 2)

# %%
t = pd.concat([egfr_df, braf_df])
t
# Out:
#                 cell           mutations
# 0        K21_B003995                  []
# 1     L22_1001000408           ['Q787Q']
# 2         A8_B001557                  []
# 3        L22_B001016                  []
# 4        C20_B002073                  []
# 5         D8_B001474                  []
# 6         C5_B002572                  []
# 7        E17_B003116                  []
# 8        A15_B000420                  []
# 9        H10_B002573                  []
# 10       I17_B002078                  []
# 11       D20_B003518                  []
# 12       M20_B003529                  []
# 13        B2_B000901                  []
# 14       C18_B002079                  []
# 15        O8_B001545                  []
# 16    H15_1001000408                  []
# 17        M7_B003527                  []
# 18       L14_B002077                  []
# 19        G1_B002572                  []
# 20       C22_B003588                  []
# 21        A8_B000863                  []
# ...

# %%
t.shape
# Out:
# (19762, 2)

# %%
keepRows = t['cell']== 'C5_B002572'
t[keepRows]
# Out:
#             cell mutations
# 6     C5_B002572        []
# 3836  C5_B002572        []

# %%
keepRows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6        True
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 9851    False
# 9852    False
# 9853    False
# 9854    False
# 9855    False
# 9856    False
# 9857    False
# 9858    False
# 9859    False
# 9860    False
# 9861    False
# 9862    False
# 9863    False
# 9864    False
# 9865    False
# 9866    False
# 9867    False
# 9868    False
# 9869    False
# 9870    False
# 9871    False
# 9872    False
# 9873    False
# 9874    False
# 9875    False
# 9876    False
# 9877    False
# 9878    False
# 9879    False
# 9880    False
# ...

# %%
t1 = pd.merge(egfr_df, braf_df, how='left')
t1
# Out:
#                 cell                                    mutations
# 0        K21_B003995                                           []
# 1     L22_1001000408                                    ['Q787Q']
# 2         A8_B001557                                           []
# 3        L22_B001016                                           []
# 4        C20_B002073                                           []
# 5         D8_B001474                                           []
# 6         C5_B002572                                           []
# 7        E17_B003116                                           []
# 8        A15_B000420                                           []
# 9        H10_B002573                                           []
# 10       I17_B002078                                           []
# 11       D20_B003518                                           []
# 12       M20_B003529                                           []
# ...

# %%
mutationsDF = pd.DataFrame(columns=['cell', 'brafMut', 'egfrMut', 'krasMut'])
mutationsDF
# Out:
# Empty DataFrame
# Columns: [cell, brafMut, egfrMut, krasMut]
# Index: []

# %%
mutationsDF['cell'] = egfr_df['cell']
mutationsDF['egfrMut'] = egfr_df['mutations']
mutationsDF
# Out:
#                 cell brafMut                                      egfrMut  \
# 0        K21_B003995     NaN                                           []
# 1     L22_1001000408     NaN                                    ['Q787Q']
# 2         A8_B001557     NaN                                           []
# 3        L22_B001016     NaN                                           []
# 4        C20_B002073     NaN                                           []
# 5         D8_B001474     NaN                                           []
# 6         C5_B002572     NaN                                           []
# 7        E17_B003116     NaN                                           []
# 8        A15_B000420     NaN                                           []
# 9        H10_B002573     NaN                                           []
# 10       I17_B002078     NaN                                           []
# 11       D20_B003518     NaN                                           []
# ...

# %%
# fill in BRAF muts -- THIS WORKS!!
for i in range(0,len(mutationsDF.index)):
    currCell = mutationsDF['cell'][i]

    rightIndex = braf_df['cell'] == currCell
    rightRow = braf_df[rightIndex]
    
    rightCell = rightRow['cell']
    rightCell = str(rightCell).split()[1]
    
    rightMut = rightRow['mutations']
    rightMut = str(rightMut).split()[1]
    
    mutationsDF['brafMut'][i] = rightMut
# Out:
# ['G466E']
# 40
# ['?']
# 394
# ['R682W']
# 873
# ['G643G']
# 1014
# ['V600E']
# 1821
# ['G643G']
# 2187
# ['L597V']
# 3141
# ['V600E']
# 3535
# ['Q609H']
# 3956
# ['?',
# 4058
# ['?']
# 4140
# ['S679N']
# 4778
# ['G643G']
# 5325
# ['A762E']
# 5727
# ['G466E']
# 5924
# ['V600E']
# 6022
# ['G643G']
# 6462
# ['V600E']
# 6754
# ['V600E']
# 6863
# ['G469R',
# 7265
# ['G643G']
# 7427
# ['V600E']
# 7473
# ['G466E']
# 7751
# ['L89L']
# 8746
# ['A762E']
# 9239
# ['A762E']
# 9471

# %%
mutationsDF
# Out:
#                 cell brafMut                                      egfrMut  \
# 0        K21_B003995      []                                           []
# 1     L22_1001000408      []                                    ['Q787Q']
# 2         A8_B001557      []                                           []
# 3        L22_B001016      []                                           []
# 4        C20_B002073      []                                           []
# 5         D8_B001474      []                                           []
# 6         C5_B002572      []                                           []
# 7        E17_B003116      []                                           []
# 8        A15_B000420      []                                           []
# 9        H10_B002573      []                                           []
# 10       I17_B002078      []                                           []
# 11       D20_B003518      []                                           []
# ...

# %%
mutationsDF.iloc[6863]
# Out:
# cell       J10_B001548
# brafMut      ['V600E']
# egfrMut             []
# krasMut            NaN
# Name: 6863, dtype: object

# %%
rightCell
# Out:
# 9311    C17_B003103
# Name: cell, dtype: object

# %%
str(rightCell)
# Out:
# '9311    C17_B003103\nName: cell, dtype: object'

# %%
str(rightCell)[1]
# Out:
# '3'

# %%
rightCell[9311]
# Out:
# 'C17_B003103'

# %%
rightIndex
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 9851    False
# 9852    False
# 9853    False
# 9854    False
# 9855    False
# 9856    False
# 9857    False
# 9858    False
# 9859    False
# 9860    False
# 9861    False
# 9862    False
# 9863    False
# 9864    False
# 9865    False
# 9866    False
# 9867    False
# 9868    False
# 9869    False
# 9870    False
# 9871    False
# 9872    False
# 9873    False
# 9874    False
# 9875    False
# 9876    False
# 9877    False
# 9878    False
# 9879    False
# 9880    False
# ...

# %%
str(rightCell).split()[1]
# Out:
# 'C17_B003103'

# %%
rightMut
# Out:
# '[]'
