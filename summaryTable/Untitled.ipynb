# %%
import pandas as pd

# %%
t = pd.read_csv('/Users/lincoln.harris/Desktop/validationTable_TEST.csv')
t
# Out:
#       cell  patient  clinical_driver_gene  clinical_mutation  \
# 0      NaN      NaN                   NaN                NaN
# 1      NaN      NaN                   NaN                NaN
# 2      NaN      NaN                   NaN                NaN
# 3      NaN      NaN                   NaN                NaN
# 4      NaN      NaN                   NaN                NaN
# 5      NaN      NaN                   NaN                NaN
# 6      NaN      NaN                   NaN                NaN
# 7      NaN      NaN                   NaN                NaN
# 8      NaN      NaN                   NaN                NaN
# 9      NaN      NaN                   NaN                NaN
# 10     NaN      NaN                   NaN                NaN
# 11     NaN      NaN                   NaN                NaN
# 12     NaN      NaN                   NaN                NaN
# 13     NaN      NaN                   NaN                NaN
# ...
