# %%
import pandas as pd

# %%
validationTable_patients = pd.read_csv('/Users/lincoln.harris/Desktop/validationTable_patients.csv')
validationTable_patients
# Out:
#          patient driver_gene          driver_mutation  \
# 0          TH248        EGFR                    del19
# 1          TH205        EGFR                    L858R
# 2          TH217        EGFR                    del19
# 3          TH185        EGFR                    L858R
# 4          TH218        EGFR                    L858R
# 5          TH172        BRAF                    V600E
# 6          TH226        EGFR                    del19
# 7          TH174          WT                      NaN
# 8          TH231         ALK                   fusion
# 9   TH179_Normal         ALK                   fusion
# 10         TH171         ALK                   fusion
# 11         TH227         ALK  intron 19 rearrangement
# 12         TH222        ROS1                   fusion
# 13         TH220         ALK                   fusion
# 14         TH158        EGFR                    del19
# 15         TH223        EGFR                    del19
# ...

# %%
validationTable_cells = pd.read_csv('/Users/lincoln.harris/Desktop/validationTable_cells_w_cov.csv')
validationTable_cells
# Out:
#                 cell       patient clinical_driver_gene clinical_mutation  \
# 0     P13_1001000339         TH169                 EGFR             del19
# 1         C1_B002572         TH266                  ALK            fusion
# 2         J2_B002573         TH266                  ALK            fusion
# 3        P22_B003116         TH231                  ALK            fusion
# 4        O22_B003191         TH226                 EGFR             del19
# 5        J12_B003529         TH171                  ALK            fusion
# 6     D14_1001000407         TH185                 EGFR             L858R
# 7        F14_B003105         TH222                 ROS1            fusion
# 8     P11_1001000340         TH169                 EGFR             del19
# 9        E21_B003930         TH222                 ROS1            fusion
# 10        N1_B002573         TH266                  ALK            fusion
# 11       C20_B000422         TH238                 BRAF             V600E
# ...

# %%
indices = validationTable_cells['patient'] == 'TH179'
validationTable_cells_179 = validationTable_cells[indices]
validationTable_cells_179
# Out:
#              cell patient clinical_driver_gene clinical_mutation  \
# 45    I11_B001559   TH179                 BRAF             V600E
# 46     E7_B001557   TH179                 BRAF             V600E
# 48    H11_B001548   TH179                 BRAF             V600E
# 53    E10_B001548   TH179                 BRAF             V600E
# 55     G8_B003577   TH179                 BRAF             V600E
# 62     N5_B001545   TH179                 BRAF             V600E
# 80    J19_B003528   TH179                 BRAF             V600E
# 81     B9_B001545   TH179                 BRAF             V600E
# 87     G1_B001548   TH179                 BRAF             V600E
# 95    H11_B003523   TH179                 BRAF             V600E
# 100   I11_B001545   TH179                 BRAF             V600E
# 102    H1_B001556   TH179                 BRAF             V600E
# 108    A1_B001543   TH179                 BRAF             V600E
# ...

# %%
indices = validationTable_cells_179['clinical_mutation_found_bool'] == 1
validationTable_cells_179[indices]
# Out:
#             cell patient clinical_driver_gene clinical_mutation  \
# 5269  M7_B001548   TH179                 BRAF             V600E
#
#              mutations_found  coverage_to_ROI  clinical_mutation_found_bool  \
# 5269  EGFR Q787Q, BRAF V600E              0.0                             1
#
#       tumorCell_bool
# 5269               0
